# %% [markdown]
# This script contains the following:
# #### 1. Import data and libraries
# #### 2. Data wrangling
# #### 3. Data cleaning
# #### 4. Exporting the data

# %% [markdown]
# # 01. Importing Libraries

# %%
import pandas as pd
import numpy as np
import os

# %%
df = pd.read_csv(r'C:\Users\tee3a\3D Objects\Project 6\02 Data\Original Data for raw data sets\flavors_of_cacao.csv', index_col = False)

# %%
path = r'C:\Users\tee3a\3D Objects\Project 6'

# %%
df = pd.read_csv(os.path.join(path, '02 Data', 'Original Data for raw data sets', 'flavors_of_cacao.csv'), index_col = False)

# %% [markdown]
# ## dataset description before check

# %%
df.shape
# Out:
# (1795, 9)

# %%
df.describe()
# Out:
#                REF  Review\nDate       Rating
# count  1795.000000   1795.000000  1795.000000
# mean   1035.904735   2012.325348     3.185933
# std     552.886365      2.927210     0.478062
# min       5.000000   2006.000000     1.000000
# 25%     576.000000   2010.000000     2.875000
# 50%    1069.000000   2013.000000     3.250000
# 75%    1502.000000   2015.000000     3.500000
# max    1952.000000   2017.000000     5.000000

# %%
df.head()
# Out:
#   Company \n(Maker-if known) Specific Bean Origin\nor Bar Name   REF  \
# 0                   A. Morin                       Agua Grande  1876
# 1                   A. Morin                             Kpime  1676
# 2                   A. Morin                            Atsane  1676
# 3                   A. Morin                             Akata  1680
# 4                   A. Morin                            Quilla  1704
#
#    Review\nDate Cocoa\nPercent Company\nLocation  Rating Bean\nType  \
# 0          2016            63%            France    3.75
# 1          2015            70%            France    2.75
# 2          2015            70%            France    3.00
# 3          2015            70%            France    3.50
# 4          2015            70%            France    3.50
#
#   Broad Bean\nOrigin
# 0           Sao Tome
# 1               Togo
# 2               Togo
# 3               Togo
# 4               Peru

# %% [markdown]
# ## Finding Missing Values

# %%
df.isnull().sum()
# Out:
# Company \n(Maker-if known)           0
# Specific Bean Origin\nor Bar Name    0
# REF                                  0
# Review\nDate                         0
# Cocoa\nPercent                       0
# Company\nLocation                    0
# Rating                               0
# Bean\nType                           1
# Broad Bean\nOrigin                   1
# dtype: int64

# %% [markdown]
# ## identifying the rows with missing values

# %%
df_nan =  df[df['Bean\nType'].isnull() == True]

# %%
df_nan
# Out:
#      Company \n(Maker-if known)        Specific Bean Origin\nor Bar Name  REF  \
# 1544                       Soma  Three Amigos(Chuao, Wild Bolivia, D.R.)  676
#
#       Review\nDate Cocoa\nPercent Company\nLocation  Rating Bean\nType  \
# 1544          2011            70%            Canada     4.0        NaN
#
#       Broad Bean\nOrigin
# 1544  Ven, Bolivia, D.R.

# %%
df_nan2 =  df[df['Broad Bean\nOrigin'].isnull() == True]

# %%
df_nan2
# Out:
#      Company \n(Maker-if known) Specific Bean Origin\nor Bar Name  REF  \
# 1072              Mast Brothers                        Madagascar  999
#
#       Review\nDate Cocoa\nPercent Company\nLocation  Rating  Bean\nType  \
# 1072          2012            72%            U.S.A.     2.5  Trinitario
#
#      Broad Bean\nOrigin
# 1072                NaN

# %% [markdown]
# ## identifying the rows with missing values

# %%
df_nan2 =  df[df['Broad Bean\nOrigin'].isnull() == True]

# %% [markdown]
# ## create a new dataframe to clean products

# %%
df_clean = df[df['Bean\nType'].isnull() == False]

# %%
df_clean = df_clean[df_clean['Broad Bean\nOrigin'].isnull() == False]

# %%
df_clean.isnull().sum()
# Out:
# Company \n(Maker-if known)           0
# Specific Bean Origin\nor Bar Name    0
# REF                                  0
# Review\nDate                         0
# Cocoa\nPercent                       0
# Company\nLocation                    0
# Rating                               0
# Bean\nType                           0
# Broad Bean\nOrigin                   0
# dtype: int64

# %% [markdown]
# ## Editing column names

# %%
df_clean.rename(columns={"Company\xa0\n(Maker-if known)": "Company Maker"}, inplace=True)
df_clean.rename(columns={"Specific Bean Origin\nor Bar Name": "Specific Bean Origin or Bar Name"}, inplace=True)
df_clean.rename(columns={"Broad Bean\nOrigin": "Broad Bean Origin"}, inplace=True)
df_clean.rename(columns={"Bean\nType": "Bean Type"}, inplace=True)
df_clean.rename(columns={"Company\nLocation": "Company Location"}, inplace=True)
df_clean.rename(columns={"Review\nDate": "Review Date"}, inplace=True)
df_clean.rename(columns={"Cocoa\nPercent": "Cocoa Percent"}, inplace=True)

# %% [markdown]
# ## Finding Duplicates

# %%
df_dups =df_clean[df_clean.duplicated()]

# %%
df_dups
# Out:
# Empty DataFrame
# Columns: [Company Maker, Specific Bean Origin or Bar Name, REF, Review Date, Cocoa Percent, Company Location, Rating, Bean Type, Broad Bean Origin]
# Index: []

# %%
df_clean.head(5)
# Out:
#   Company Maker Specific Bean Origin or Bar Name   REF  Review Date  \
# 0      A. Morin                      Agua Grande  1876         2016
# 1      A. Morin                            Kpime  1676         2015
# 2      A. Morin                           Atsane  1676         2015
# 3      A. Morin                            Akata  1680         2015
# 4      A. Morin                           Quilla  1704         2015
#
#   Cocoa Percent Company Location  Rating Bean Type Broad Bean Origin
# 0           63%           France    3.75                    Sao Tome
# 1           70%           France    2.75                        Togo
# 2           70%           France    3.00                        Togo
# 3           70%           France    3.50                        Togo
# 4           70%           France    3.50                        Peru

# %% [markdown]
# ## check for mixed types

# %%
for col in df_clean.columns.tolist():
  weird = (df_clean[[col]].applymap(type) != df_clean[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_clean[weird]) > 0:
    print (col)

# %%
df_clean.shape
# Out:
# (1793, 9)

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1793 entries, 0 to 1794
# Data columns (total 9 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Company Maker                     1793 non-null   object
#  1   Specific Bean Origin or Bar Name  1793 non-null   object
#  2   REF                               1793 non-null   int64
#  3   Review Date                       1793 non-null   int64
#  4   Cocoa Percent                     1793 non-null   object
#  5   Company Location                  1793 non-null   object
#  6   Rating                            1793 non-null   float64
#  7   Bean Type                         1793 non-null   object
#  8   Broad Bean Origin                 1793 non-null   object
# dtypes: float64(1), int64(2), object(6)
# memory usage: 140.1+ KB

# %%
df_clean
# Out:
#      Company Maker Specific Bean Origin or Bar Name   REF  Review Date  \
# 0         A. Morin                      Agua Grande  1876         2016
# 1         A. Morin                            Kpime  1676         2015
# 2         A. Morin                           Atsane  1676         2015
# 3         A. Morin                            Akata  1680         2015
# 4         A. Morin                           Quilla  1704         2015
# ...            ...                              ...   ...          ...
# 1790        Zotter                             Peru   647         2011
# 1791        Zotter                            Congo   749         2011
# 1792        Zotter                     Kerala State   749         2011
# 1793        Zotter                     Kerala State   781         2011
# 1794        Zotter               Brazil, Mitzi Blue   486         2010
#
#      Cocoa Percent Company Location  Rating  Bean Type Broad Bean Origin
# ...

# %%
df_clean.dtypes
# Out:
# Company Maker                        object
# Specific Bean Origin or Bar Name     object
# REF                                   int64
# Review Date                           int64
# Cocoa Percent                        object
# Company Location                     object
# Rating                              float64
# Bean Type                            object
# Broad Bean Origin                    object
# dtype: object

# %%
data_dict = df.to_dict('index')

# %%
data_dict
# Out:
# {0: {'Company\xa0\n(Maker-if known)': 'A. Morin',
#   'Specific Bean Origin\nor Bar Name': 'Agua Grande',
#   'REF': 1876,
#   'Review\nDate': 2016,
#   'Cocoa\nPercent': '63%',
#   'Company\nLocation': 'France',
#   'Rating': 3.75,
#   'Bean\nType': '\xa0',
#   'Broad Bean\nOrigin': 'Sao Tome'},
#  1: {'Company\xa0\n(Maker-if known)': 'A. Morin',
#   'Specific Bean Origin\nor Bar Name': 'Kpime',
#   'REF': 1676,
#   'Review\nDate': 2015,
#   'Cocoa\nPercent': '70%',
#   'Company\nLocation': 'France',
#   'Rating': 2.75,
#   'Bean\nType': '\xa0',
#   'Broad Bean\nOrigin': 'Togo'},
#  2: {'Company\xa0\n(Maker-if known)': 'A. Morin',
#   'Specific Bean Origin\nor Bar Name': 'Atsane',
#   'REF': 1676,
#   'Review\nDate': 2015,
#   'Cocoa\nPercent': '70%',
#   'Company\nLocation': 'France',
#   'Rating': 3.0,
#   'Bean\nType': '\xa0',
#   'Broad Bean\nOrigin': 'Togo'},
#  3: {'Company\xa0\n(Maker-if known)': 'A. Morin',
#   'Specific Bean Origin\nor Bar Name': 'Akata',
#   'REF': 1680,
# ...

# %% [markdown]
# ## dataset description after check

# %%
df_clean.shape
# Out:
# (1793, 9)

# %%
df_clean.describe()
# Out:
#                REF  Review Date       Rating
# count  1793.000000  1793.000000  1793.000000
# mean   1036.126046  2012.326269     3.185862
# std     553.128742     2.928666     0.477668
# min       5.000000  2006.000000     1.000000
# 25%     576.000000  2010.000000     3.000000
# 50%    1073.000000  2013.000000     3.250000
# 75%    1502.000000  2015.000000     3.500000
# max    1952.000000  2017.000000     5.000000

# %%
df_clean['Cocoa Percent'].describe()
# Out:
# count     1793
# unique      45
# top        70%
# freq       671
# Name: Cocoa Percent, dtype: object

# %% [markdown]
# ## checking and editing Broad Bean Origin column

# %%
df_clean['Broad Bean Origin'].value_counts(dropna = False)
# Out:
# Venezuela                214
# Ecuador                  193
# Peru                     165
# Madagascar               145
# Dominican Republic       141
#                         ...
# Nigeria                    1
# Peru, Belize               1
# Peru, Mad., Dom. Rep.      1
# PNG, Vanuatu, Mad          1
# Venezuela, Carribean       1
# Name: Broad Bean Origin, Length: 99, dtype: int64

# %%
df_clean.loc[939]
# Out:
# Company Maker                       La Maison du Chocolat (Valrhona)
# Specific Bean Origin or Bar Name                         Cuana, 2008
# REF                                                              230
# Review Date                                                     2008
# Cocoa Percent                                                    74%
# Company Location                                              France
# Rating                                                           3.5
# Bean Type                                                      Blend
# Broad Bean Origin                            Ven., Indonesia, Ecuad.
# Name: 939, dtype: object

# %%
df_clean.loc[939] = ['La Maison du Chocolat (Valrhona)','Cuana, 2008','230','2008','74%','France','3.5','Blend','Ven., Indonesia, Ecuad.']

# %%
df_clean.loc[939, ['Broad Bean Origin']]
# Out:
# Broad Bean Origin    Ven., Indonesia, Ecuad.
# Name: 939, dtype: object

# %%
df_clean.loc[939, ['Broad Bean Origin']] = ['Indonesia']

# %%
df_clean.loc[939, ['Specific Bean Origin or Bar Name']]
df_clean.loc[939, ['Specific Bean Origin or Bar Name']] = ['Cuana']

# %%
df_clean.loc[939]
# Out:
# Company Maker                       La Maison du Chocolat (Valrhona)
# Specific Bean Origin or Bar Name                               Cuana
# REF                                                              230
# Review Date                                                     2008
# Cocoa Percent                                                    74%
# Company Location                                              France
# Rating                                                           3.5
# Bean Type                                                      Blend
# Broad Bean Origin                                          Indonesia
# Name: 939, dtype: object

# %%
df_clean.loc[1789, ['Broad Bean Origin']]
df_clean.loc[1789, ['Broad Bean Origin']] = ['']

# %%
df_clean.loc[1778]
# Out:
# Company Maker                        Zotter
# Specific Bean Origin or Bar Name        Raw
# REF                                    1205
# Review Date                            2014
# Cocoa Percent                           80%
# Company Location                    Austria
# Rating                                 2.75
# Bean Type
# Broad Bean Origin
# Name: 1778, dtype: object

# %%
df_clean.loc[23]
# Out:
# Company Maker                                        Acalli
# Specific Bean Origin or Bar Name    Chulucanas, El Platanal
# REF                                                    1462
# Review Date                                            2015
# Cocoa Percent                                           70%
# Company Location                                     U.S.A.
# Rating                                                 3.75
# Bean Type
# Broad Bean Origin                                      Peru
# Name: 23, dtype: object

# %%
df_clean.loc[23] = ['Acalli','Chulucanas, El Platanal, 2008','230','2008','74%','France','3.5','Blend','Ven., Indonesia, Ecuad.']

# %% [markdown]
# ## changing U.K and U.S.A to United Kingdom and United States in column 'Company Location'

# %%
df_clean['Company Location'] = df_clean['Company Location'].replace('U.S.A.','United States')
df_clean['Company Location'] = df_clean['Company Location'].replace('U.K.','United Kingdom')
df_clean['Company Location'] = df_clean['Company Location'].replace('Eucador','Ecuador')
df_clean['Company Location'] = df_clean['Company Location'].replace('Domincan Republic','Dominican Republic')
df_clean['Company Location'] = df_clean['Company Location'].replace('Scotland','United Kingdom')
df_clean['Company Location'] = df_clean['Company Location'].replace('Wales','United Kingdom')
df_clean['Company Location'] = df_clean['Company Location'].replace('Lithuania','United Kingdom')
df_clean['Company Location'] = df_clean['Company Location'].replace('Amsterdam','United Kingdom')
df_clean['Company Location'] = df_clean['Company Location'].replace('St. Lucia','United States')
df_clean['Company Location'] = df_clean['Company Location'].replace('Martinique','United States')
df_clean['Company Location'] = df_clean['Company Location'].replace('Sao Tome and Principe','São Tomé and Principe')
df_clean['Company Location'] = df_clean['Company Location'].replace('Grenada','United States')
df_clean['Company Location'] = df_clean['Company Location'].replace('Niacragua','United States')
df_clean['Company Location'] = df_clean['Company Location'].replace('Wales','United Kingdom') 
df_clean['Company Location'].value_counts(dropna = False)
# Out:
# United States         769
# France                157
# Canada                124
# United Kingdom        117
# Italy                  63
# Ecuador                55
# Australia              49
# Belgium                40
# Switzerland            38
# Germany                35
# Austria                26
# Spain                  25
# Colombia               23
# Hungary                22
# Venezuela              20
# Brazil                 17
# Peru                   17
# Madagascar             17
# Japan                  17
# New Zealand            17
# Denmark                15
# Vietnam                11
# Guatemala              10
# Israel                  9
# Argentina               9
# Costa Rica              9
# Poland                  8
# Honduras                6
# Dominican Republic      5
# Nicaragua               5
# Sweden                  5
# South Korea             5
# Sao Tome                4
# Fiji                    4
# Mexico                  4
# ...

# %% [markdown]
# ## changing '\xa0' to 'xao'  in column 'Bean Type'

# %%
df_clean['Bean Type'] = df_clean['Bean Type'].replace('\xa0','xao')

# %%
df_clean['Bean Type'].value_counts(dropna = False)
# Out:
# xao                         886
# Trinitario                  418
# Criollo                     153
# Forastero                    87
# Forastero (Nacional)         52
# Blend                        42
# Criollo, Trinitario          39
# Forastero (Arriba)           37
# Criollo (Porcelana)          10
# Trinitario, Criollo           9
# Forastero (Parazinho)         8
# Forastero (Arriba) ASS        6
# Nacional (Arriba)             3
# Matina                        3
# EET                           3
# Beniano                       3
# Criollo (Ocumare 61)          2
# Trinitario, Forastero         2
# Trinitario (85% Criollo)      2
# Forastero (Catongo)           2
# Criollo, Forastero            2
# Amazon, ICS                   2
# Criollo (Amarru)              2
# Amazon mix                    2
# Nacional                      2
# Criollo (Ocumare)             1
# Criollo (Ocumare 67)          1
# Trinitario, TCGA              1
# Trinitario (Amelonado)        1
# ...

# %% [markdown]
# ## new data dictionary

# %%
data_dict1 = df_clean.to_dict('index')

# %%
data_dict1
# Out:
# {0: {'Company Maker': 'A. Morin',
#   'Specific Bean Origin or Bar Name': 'Agua Grande',
#   'REF': 1876,
#   'Review Date': 2016,
#   'Cocoa Percent': '63%',
#   'Company Location': 'France',
#   'Rating': 3.75,
#   'Bean Type': 'xao',
#   'Broad Bean Origin': 'Sao Tome'},
#  1: {'Company Maker': 'A. Morin',
#   'Specific Bean Origin or Bar Name': 'Kpime',
#   'REF': 1676,
#   'Review Date': 2015,
#   'Cocoa Percent': '70%',
#   'Company Location': 'France',
#   'Rating': 2.75,
#   'Bean Type': 'xao',
#   'Broad Bean Origin': 'Togo'},
#  2: {'Company Maker': 'A. Morin',
#   'Specific Bean Origin or Bar Name': 'Atsane',
#   'REF': 1676,
#   'Review Date': 2015,
#   'Cocoa Percent': '70%',
#   'Company Location': 'France',
#   'Rating': 3.0,
#   'Bean Type': 'xao',
#   'Broad Bean Origin': 'Togo'},
#  3: {'Company Maker': 'A. Morin',
#   'Specific Bean Origin or Bar Name': 'Akata',
#   'REF': 1680,
#   'Review Date': 2015,
#   'Cocoa Percent': '70%',
#   'Company Location': 'France',
# ...

# %% [markdown]
# ## checking and cleaning empty data

# %%
df_clean.isnull().sum()
# Out:
# Company Maker                       0
# Specific Bean Origin or Bar Name    0
# REF                                 0
# Review Date                         0
# Cocoa Percent                       0
# Company Location                    0
# Rating                              0
# Bean Type                           0
# Broad Bean Origin                   0
# dtype: int64

# %% [markdown]
# #### converting 'Cocoa Percent' from object- str to  float64

# %%
df_clean_3 = df_clean

# %%
df_clean_3['Cocoa Percent'] = df_clean_3['Cocoa Percent'].str.replace('%','').astype(np.float64)

# %% [markdown]
# #### converting 'REF' and 'Review Date' from object- str to  int64

# %%
df_clean_3['Rating'] = df_clean_3['Rating'].astype('float64')
df_clean_3['REF'] = df_clean_3['REF'].astype('int64')
df_clean_3['Review Date'] = df_clean_3['Review Date'].astype('int64')

# %%
df_clean_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1793 entries, 0 to 1794
# Data columns (total 9 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Company Maker                     1793 non-null   object
#  1   Specific Bean Origin or Bar Name  1793 non-null   object
#  2   REF                               1793 non-null   int64
#  3   Review Date                       1793 non-null   int64
#  4   Cocoa Percent                     1793 non-null   float64
#  5   Company Location                  1793 non-null   object
#  6   Rating                            1793 non-null   float64
#  7   Bean Type                         1793 non-null   object
#  8   Broad Bean Origin                 1793 non-null   object
# dtypes: float64(2), int64(2), object(5)
# memory usage: 204.6+ KB

# %%
df_airline = df_clean_3

# %%
df_airline.tail(1)
# Out:
#      Company Maker Specific Bean Origin or Bar Name  REF  Review Date  \
# 1794        Zotter               Brazil, Mitzi Blue  486         2010
#
#       Cocoa Percent Company Location  Rating Bean Type Broad Bean Origin
# 1794           65.0          Austria     3.0       xao            Brazil

# %%
df_airline['REF']
# Out:
# 0       1876
# 1       1676
# 2       1676
# 3       1680
# 4       1704
#         ...
# 1790     647
# 1791     749
# 1792     749
# 1793     781
# 1794     486
# Name: REF, Length: 1793, dtype: int64

# %%
data = df_clean

# %%
# Converting 'Review Date' to object
data['Review Date'] = data['Review Date'].astype('str')

# %%
 ## Exporting the data
df_airline.to_csv(os.path.join(path, '02 Data','Prepared Data for storing any manipulated data sets', 'flavors_of_cacao_checked.csv'))

# %%
 ## Exporting the data
data.to_csv(os.path.join(path, '02 Data','Prepared Data for storing any manipulated data sets', 'flavors_of_cacao_checked1.csv'))

# %% [markdown]
# #### Converting the review date

# %%
df_airline1 = df_airline

# %%
df_airline.loc[0,"Review Date"]="2016-02-01"
df_airline.loc[1,"Review Date"]="2015-02-01"
df_airline.loc[2,"Review Date"]="2015-03-01"
df_airline.loc[3,"Review Date"]="2015-04-01"
df_airline.loc[4,"Review Date"]="2015-05-01"
df_airline.loc[5,"Review Date"]="2015-06-01"
df_airline.loc[6,"Review Date"]="2014-02-01"
df_airline.loc[7,"Review Date"]="2015-06-01"
df_airline.loc[8,"Review Date"]="2015-08-01"
df_airline.loc[9,"Review Date"]="2015-09-01"
df_airline.loc[10,"Review Date"]="2015-10-01"
df_airline.loc[11,"Review Date"]="2015-11-01"
df_airline.loc[12,"Review Date"]="2015-12-01"
df_airline.loc[13,"Review Date"]="2016-03-01"
df_airline.loc[14,"Review Date"]="2016-04-01"
df_airline.loc[15,"Review Date"]="2016-05-01"
df_airline.loc[16,"Review Date"]="2016-06-01"
df_airline.loc[17,"Review Date"]="2016-07-01"
df_airline.loc[18,"Review Date"]="2016-08-01"
df_airline.loc[19,"Review Date"]="2016-09-01"
df_airline.loc[20,"Review Date"]="2016-10-01"
df_airline.loc[21,"Review Date"]="2016-11-01"
df_airline.loc[22,"Review Date"]="2016-12-01"
df_airline.loc[23,"Review Date"]="2014-03-01"
df_airline.loc[24,"Review Date"]="2014-04-01"
df_airline.loc[25,"Review Date"]="2014-05-01"
df_airline.loc[26,"Review Date"]="2014-06-01"
df_airline.loc[27,"Review Date"]="2014-07-01"
df_airline.loc[28,"Review Date"]="2014-08-01"
df_airline.loc[29,"Review Date"]="2014-09-01"
df_airline.loc[30,"Review Date"]="2014-10-01"
df_airline.loc[31,"Review Date"]="2014-11-01"
df_airline.loc[32,"Review Date"]="2014-12-01"
df_airline.loc[33,"Review Date"]="2013-02-01"
df_airline.loc[34,"Review Date"]="2013-03-01"
df_airline.loc[35,"Review Date"]="2013-04-01"
df_airline.loc[36,"Review Date"]="2013-05-01"
df_airline.loc[37,"Review Date"]="2013-06-01"
df_airline.loc[38,"Review Date"]="2013-07-01"
df_airline.loc[39,"Review Date"]="2013-08-01"
df_airline.loc[40,"Review Date"]="2013-09-01"
df_airline.loc[41,"Review Date"]="2013-10-01"
df_airline.loc[42,"Review Date"]="2013-11-01"
df_airline.loc[43,"Review Date"]="2013-12-01"
df_airline.loc[44,"Review Date"]="2012-02-01"
df_airline.loc[45,"Review Date"]="2012-03-01"
df_airline.loc[46,"Review Date"]="2012-04-01"
df_airline.loc[47,"Review Date"]="2012-05-01"
df_airline.loc[48,"Review Date"]="2012-06-01"
df_airline.loc[49,"Review Date"]="2012-07-01"
df_airline.loc[50,"Review Date"]="2012-08-01"
df_airline.loc[51,"Review Date"]="2012-09-01"
df_airline.loc[52,"Review Date"]="2012-10-01"
df_airline.loc[53,"Review Date"]="2012-11-01"
df_airline.loc[54,"Review Date"]="2012-12-01"
df_airline.loc[55,"Review Date"]="2011-02-01"
df_airline.loc[56,"Review Date"]="2011-03-01"
df_airline.loc[57,"Review Date"]="2011-04-01"
df_airline.loc[58,"Review Date"]="2011-04-01"
df_airline.loc[59,"Review Date"]="2011-06-01"
df_airline.loc[60,"Review Date"]="2011-07-01"
df_airline.loc[61,"Review Date"]="2011-08-01"
df_airline.loc[62,"Review Date"]="2011-09-01"
df_airline.loc[63,"Review Date"]="2011-10-01"
df_airline.loc[64,"Review Date"]="2011-11-01"
df_airline.loc[65,"Review Date"]="2011-12-01"
df_airline.loc[66,"Review Date"]="2010-03-01"
df_airline.loc[67,"Review Date"]="2010-02-01"
df_airline.loc[68,"Review Date"]="2010-04-01"
df_airline.loc[69,"Review Date"]="2010-05-01"
df_airline.loc[70,"Review Date"]="2010-06-01"
df_airline.loc[71,"Review Date"]="2010-07-01"
df_airline.loc[72,"Review Date"]="2010-08-01"
df_airline.loc[73,"Review Date"]="2010-09-01"
df_airline.loc[74,"Review Date"]="2010-10-01"
df_airline.loc[75,"Review Date"]="2010-11-01"
df_airline.loc[76,"Review Date"]="2010-12-01"
df_airline.loc[77,"Review Date"]="2009-02-01"
df_airline.loc[78,"Review Date"]="2009-03-01"
df_airline.loc[79,"Review Date"]="2009-04-01"
df_airline.loc[80,"Review Date"]="2009-05-01"
df_airline.loc[81,"Review Date"]="2009-06-01"
df_airline.loc[82,"Review Date"]="2009-07-01"
df_airline.loc[83,"Review Date"]="2009-08-01"
df_airline.loc[84,"Review Date"]="2009-09-01"
df_airline.loc[85,"Review Date"]="2009-10-01"
df_airline.loc[86,"Review Date"]="2009-11-01"
df_airline.loc[87,"Review Date"]="2009-12-01"
df_airline.loc[88,"Review Date"]="2008-02-01"
df_airline.loc[89,"Review Date"]="2008-03-01"
df_airline.loc[90,"Review Date"]="2008-04-01"
df_airline.loc[91,"Review Date"]="2008-05-01"
df_airline.loc[92,"Review Date"]="2008-06-01"
df_airline.loc[93,"Review Date"]="2008-07-01"
df_airline.loc[94,"Review Date"]="2008-08-01"
df_airline.loc[95,"Review Date"]="2008-09-01"
df_airline.loc[96,"Review Date"]="2008-10-01"
df_airline.loc[97,"Review Date"]="2008-11-01"
df_airline.loc[98,"Review Date"]="2008-12-01"
df_airline.loc[99,"Review Date"]="2007-02-01"
df_airline.loc[100,"Review Date"]="2007-03-01"
df_airline.loc[101,"Review Date"]="2007-04-01"
df_airline.loc[102,"Review Date"]="2007-05-01"
df_airline.loc[103,"Review Date"]="2007-06-01"
df_airline.loc[104,"Review Date"]="2007-07-01"
df_airline.loc[105,"Review Date"]="2007-08-01"
df_airline.loc[106,"Review Date"]="2007-09-01"
df_airline.loc[107,"Review Date"]="2007-10-01"
df_airline.loc[108,"Review Date"]="2007-11-01"
df_airline.loc[109,"Review Date"]="2007-12-01"
df_airline.loc[110,"Review Date"]="2006-02-01"
df_airline.loc[111,"Review Date"]="2006-03-01"
df_airline.loc[112,"Review Date"]="2006-04-01"
df_airline.loc[113,"Review Date"]="2006-07-01"
df_airline.loc[114,"Review Date"]="2006-05-01"
df_airline.loc[115,"Review Date"]="2006-06-01"
df_airline.loc[116,"Review Date"]="2006-08-01"
df_airline.loc[117,"Review Date"]="2006-09-01"
df_airline.loc[118,"Review Date"]="2006-10-01"
df_airline.loc[119,"Review Date"]="2006-11-01"
df_airline.loc[120,"Review Date"]="2017-02-01"
df_airline.loc[121,"Review Date"]="2017-03-01"
df_airline.loc[122,"Review Date"]="2017-04-01"
df_airline.loc[123,"Review Date"]="2017-05-01"
df_airline.loc[124,"Review Date"]="2017-06-01"
df_airline.loc[125,"Review Date"]="2017-07-01"
df_airline.loc[126,"Review Date"]="2017-08-01"
df_airline.loc[127,"Review Date"]="2017-09-01"
df_airline.loc[128,"Review Date"]="2017-10-01"
df_airline.loc[129,"Review Date"]="2017-11-01"
df_airline.loc[130,"Review Date"]="2017-12-01"
df_airline.loc[131,"Review Date"]="2017-01-01"
df_airline.loc[132,"Review Date"]="2017-01-01"
df_airline.loc[133,"Review Date"]="2017-01-01"
df_airline.loc[134,"Review Date"]="2017-01-01"
df_airline.loc[135,"Review Date"]="2017-01-02"
df_airline.loc[136,"Review Date"]="2017-01-03"
df_airline.loc[137,"Review Date"]="2017-01-04"
df_airline.loc[138,"Review Date"]="2017-01-05"
df_airline.loc[139,"Review Date"]="2017-01-06"
df_airline.loc[140,"Review Date"]="2017-01-07"
df_airline.loc[141,"Review Date"]="2017-01-08"
df_airline.loc[142,"Review Date"]="2017-01-09"
df_airline.loc[143,"Review Date"]="2017-01-10"
df_airline.loc[144,"Review Date"]="2017-01-11"
df_airline.loc[145,"Review Date"]="2017-01-12"
df_airline.loc[146,"Review Date"]="2017-01-13"
df_airline.loc[147,"Review Date"]="2017-01-14"
df_airline.loc[148,"Review Date"]="2017-01-15"
df_airline.loc[149,"Review Date"]="2017-01-16"
df_airline.loc[150,"Review Date"]="2017-01-17"
df_airline.loc[151,"Review Date"]="2017-01-18"
df_airline.loc[152,"Review Date"]="2017-01-19"
df_airline.loc[153,"Review Date"]="2017-01-20"
df_airline.loc[154,"Review Date"]="2017-01-21"
df_airline.loc[155,"Review Date"]="2017-01-22"
df_airline.loc[156,"Review Date"]="2017-01-23"
df_airline.loc[157,"Review Date"]="2017-01-24"
df_airline.loc[158,"Review Date"]="2017-01-25"
df_airline.loc[159,"Review Date"]="2017-01-26"
df_airline.loc[160,"Review Date"]="2017-01-27"
df_airline.loc[161,"Review Date"]="2017-01-28"
df_airline.loc[162,"Review Date"]="2017-01-29"
df_airline.loc[163,"Review Date"]="2017-01-30"
df_airline.loc[164,"Review Date"]="2016-01-31"
df_airline.loc[165,"Review Date"]="2016-01-01"
df_airline.loc[166,"Review Date"]="2016-01-02"
df_airline.loc[167,"Review Date"]="2016-01-03"
df_airline.loc[168,"Review Date"]="2016-01-04"
df_airline.loc[169,"Review Date"]="2016-01-05"
df_airline.loc[171,"Review Date"]="2016-01-06"
df_airline.loc[172,"Review Date"]="2016-01-07"
df_airline.loc[173,"Review Date"]="2016-01-08"
df_airline.loc[174,"Review Date"]="2016-01-09"
df_airline.loc[175,"Review Date"]="2016-01-10"
df_airline.loc[176,"Review Date"]="2016-01-11"
df_airline.loc[177,"Review Date"]="2016-01-12"
df_airline.loc[178,"Review Date"]="2016-01-13"
df_airline.loc[179,"Review Date"]="2016-01-14"
df_airline.loc[180,"Review Date"]="2016-01-15"
df_airline.loc[181,"Review Date"]="2016-01-16"
df_airline.loc[182,"Review Date"]="2016-01-17"
df_airline.loc[183,"Review Date"]="2016-01-18"
df_airline.loc[184,"Review Date"]="2016-01-19"
df_airline.loc[185,"Review Date"]="2016-01-20"
df_airline.loc[186,"Review Date"]="2016-01-21"
df_airline.loc[187,"Review Date"]="2016-01-22"
df_airline.loc[188,"Review Date"]="2016-01-23"
df_airline.loc[189,"Review Date"]="2016-01-24"
df_airline.loc[190,"Review Date"]="2016-01-25"
df_airline.loc[191,"Review Date"]="2016-01-26"
df_airline.loc[192,"Review Date"]="2016-01-27"
df_airline.loc[193,"Review Date"]="2016-01-28"
df_airline.loc[194,"Review Date"]="2016-01-29"
df_airline.loc[195,"Review Date"]="2016-01-30"
df_airline.loc[196,"Review Date"]="2016-01-31"
df_airline.loc[197,"Review Date"]="2015-01-01"
df_airline.loc[198,"Review Date"]="2015-01-02"
df_airline.loc[199,"Review Date"]="2015-01-03"
df_airline.loc[200,"Review Date"]="2015-01-04"
df_airline.loc[201,"Review Date"]="2015-01-05"
df_airline.loc[202,"Review Date"]="2015-01-06"
df_airline.loc[203,"Review Date"]="2015-01-07"
df_airline.loc[204,"Review Date"]="2015-01-08"
df_airline.loc[205,"Review Date"]="2015-01-09"
df_airline.loc[206,"Review Date"]="2015-01-10"
df_airline.loc[207,"Review Date"]="2015-01-11"
df_airline.loc[208,"Review Date"]="2015-01-12"
df_airline.loc[209,"Review Date"]="2015-01-13"
df_airline.loc[210,"Review Date"]="2015-01-14"
df_airline.loc[211,"Review Date"]="2015-01-15"
df_airline.loc[212,"Review Date"]="2015-01-16"
df_airline.loc[213,"Review Date"]="2015-01-17"
df_airline.loc[214,"Review Date"]="2015-01-18"
df_airline.loc[215,"Review Date"]="2015-01-19"
df_airline.loc[216,"Review Date"]="2015-01-20"
df_airline.loc[217,"Review Date"]="2015-01-21"
df_airline.loc[218,"Review Date"]="2015-01-22"
df_airline.loc[219,"Review Date"]="2015-01-23"
df_airline.loc[220,"Review Date"]="2015-01-24"
df_airline.loc[221,"Review Date"]="2015-01-25"
df_airline.loc[222,"Review Date"]="2015-01-26"
df_airline.loc[223,"Review Date"]="2015-01-27"
df_airline.loc[224,"Review Date"]="2015-01-28"
df_airline.loc[225,"Review Date"]="2015-01-29"
df_airline.loc[226,"Review Date"]="2015-01-30"
df_airline.loc[227,"Review Date"]="2015-01-31"
df_airline.loc[228,"Review Date"]="2014-01-01"
df_airline.loc[229,"Review Date"]="2014-01-02"
df_airline.loc[230,"Review Date"]="2014-01-03"
df_airline.loc[231,"Review Date"]="2014-01-04"
df_airline.loc[232,"Review Date"]="2014-01-05"
df_airline.loc[233,"Review Date"]="2014-01-06"
df_airline.loc[234,"Review Date"]="2014-01-07"
df_airline.loc[235,"Review Date"]="2014-01-08"
df_airline.loc[236,"Review Date"]="2014-01-09"
df_airline.loc[237,"Review Date"]="2014-01-10"
df_airline.loc[238,"Review Date"]="2014-01-11"
df_airline.loc[239,"Review Date"]="2014-01-12"
df_airline.loc[240,"Review Date"]="2014-01-13"
df_airline.loc[242,"Review Date"]="2014-01-14"
df_airline.loc[243,"Review Date"]="2014-01-15"
df_airline.loc[244,"Review Date"]="2014-01-16"
df_airline.loc[245,"Review Date"]="2014-01-17"
df_airline.loc[246,"Review Date"]="2014-01-18"
df_airline.loc[247,"Review Date"]="2014-01-19"
df_airline.loc[248,"Review Date"]="2014-01-20"
df_airline.loc[249,"Review Date"]="2014-01-21"
df_airline.loc[250,"Review Date"]="2014-01-22"
df_airline.loc[251,"Review Date"]="2014-01-23"
df_airline.loc[252,"Review Date"]="2014-01-24"
df_airline.loc[253,"Review Date"]="2014-01-25"
df_airline.loc[254,"Review Date"]="2014-01-26"
df_airline.loc[255,"Review Date"]="2014-01-27"
df_airline.loc[256,"Review Date"]="2014-01-28"
df_airline.loc[257,"Review Date"]="2014-01-29"
df_airline.loc[257,"Review Date"]="2014-01-30"
df_airline.loc[260,"Review Date"]="2014-01-31"
df_airline.loc[262,"Review Date"]="2013-01-01"
df_airline.loc[263,"Review Date"]="2013-01-02"
df_airline.loc[264,"Review Date"]="2013-01-03"
df_airline.loc[265,"Review Date"]="2013-01-04"
df_airline.loc[266,"Review Date"]="2013-01-05"
df_airline.loc[267,"Review Date"]="2013-01-06"
df_airline.loc[268,"Review Date"]="2013-01-07"
df_airline.loc[269,"Review Date"]="2013-01-08"
df_airline.loc[270,"Review Date"]="2013-01-09"
df_airline.loc[271,"Review Date"]="2013-01-10"
df_airline.loc[272,"Review Date"]="2013-01-11"
df_airline.loc[273,"Review Date"]="2013-01-12"
df_airline.loc[274,"Review Date"]="2013-01-13"
df_airline.loc[275,"Review Date"]="2013-01-14"
df_airline.loc[276,"Review Date"]="2013-01-15"
df_airline.loc[277,"Review Date"]="2013-01-16"
df_airline.loc[278,"Review Date"]="2013-01-17"
df_airline.loc[279,"Review Date"]="2013-01-18"
df_airline.loc[280,"Review Date"]="2013-01-19"
df_airline.loc[281,"Review Date"]="2013-01-20"
df_airline.loc[282,"Review Date"]="2013-01-21"
df_airline.loc[283,"Review Date"]="2013-01-22"
df_airline.loc[284,"Review Date"]="2013-01-23"
df_airline.loc[285,"Review Date"]="2013-01-24"
df_airline.loc[286,"Review Date"]="2013-01-25"
df_airline.loc[287,"Review Date"]="2013-01-26"
df_airline.loc[288,"Review Date"]="2013-01-27"
df_airline.loc[289,"Review Date"]="2013-01-28"
df_airline.loc[290,"Review Date"]="2013-01-29"
df_airline.loc[291,"Review Date"]="2013-01-30"
df_airline.loc[292,"Review Date"]="2013-01-31"
df_airline.loc[293,"Review Date"]="2012-01-01"
df_airline.loc[294,"Review Date"]="2012-01-02"
df_airline.loc[295,"Review Date"]="2012-01-03"
df_airline.loc[296,"Review Date"]="2012-01-04"
df_airline.loc[297,"Review Date"]="2012-01-05"
df_airline.loc[298,"Review Date"]="2012-01-06"
df_airline.loc[299,"Review Date"]="2012-01-07"
df_airline.loc[301,"Review Date"]="2012-01-08"
df_airline.loc[302,"Review Date"]="2012-01-09"
df_airline.loc[303,"Review Date"]="2012-01-10"
df_airline.loc[304,"Review Date"]="2012-01-11"
df_airline.loc[305,"Review Date"]="2012-01-12"
df_airline.loc[306,"Review Date"]="2012-01-13"
df_airline.loc[307,"Review Date"]="2012-01-14"
df_airline.loc[308,"Review Date"]="2012-01-15"
df_airline.loc[309,"Review Date"]="2012-01-16"
df_airline.loc[310,"Review Date"]="2012-01-17"
df_airline.loc[311,"Review Date"]="2012-01-18"
df_airline.loc[312,"Review Date"]="2012-01-19"
df_airline.loc[313,"Review Date"]="2012-01-20"
df_airline.loc[314,"Review Date"]="2012-01-21"
df_airline.loc[315,"Review Date"]="2012-01-22"
df_airline.loc[316,"Review Date"]="2012-01-23"
df_airline.loc[317,"Review Date"]="2012-01-24"
df_airline.loc[318,"Review Date"]="2012-01-25"
df_airline.loc[319,"Review Date"]="2012-01-26"
df_airline.loc[320,"Review Date"]="2012-01-27"
df_airline.loc[321,"Review Date"]="2012-01-28"
df_airline.loc[322,"Review Date"]="2012-01-29"
df_airline.loc[323,"Review Date"]="2012-01-30"
df_airline.loc[324,"Review Date"]="2012-01-31"
df_airline.loc[325,"Review Date"]="2012-01-01"
df_airline.loc[326,"Review Date"]="2012-01-31"
df_airline.loc[327,"Review Date"]="2012-01-31"
df_airline.loc[328,"Review Date"]="2012-01-31"
df_airline.loc[329,"Review Date"]="2011-01-01"
df_airline.loc[330,"Review Date"]="2011-01-02"
df_airline.loc[331,"Review Date"]="2011-01-03"
df_airline.loc[332,"Review Date"]="2011-01-04"
df_airline.loc[333,"Review Date"]="2011-01-05"
df_airline.loc[334,"Review Date"]="2011-01-06"
df_airline.loc[335,"Review Date"]="2011-01-07"
df_airline.loc[336,"Review Date"]="2011-01-08"
df_airline.loc[337,"Review Date"]="2011-01-09"
df_airline.loc[338,"Review Date"]="2011-01-10"
df_airline.loc[339,"Review Date"]="2011-01-11"
df_airline.loc[340,"Review Date"]="2011-01-12"
df_airline.loc[341,"Review Date"]="2011-01-13"
df_airline.loc[342,"Review Date"]="2011-01-14"
df_airline.loc[343,"Review Date"]="2011-01-15"
df_airline.loc[344,"Review Date"]="2011-01-16"
df_airline.loc[346,"Review Date"]="2011-01-17"
df_airline.loc[347,"Review Date"]="2011-01-18"
df_airline.loc[348,"Review Date"]="2011-01-19"
df_airline.loc[349,"Review Date"]="2011-01-20"
df_airline.loc[350,"Review Date"]="2011-01-21"
df_airline.loc[351,"Review Date"]="2011-01-22"
df_airline.loc[352,"Review Date"]="2011-01-23"
df_airline.loc[353,"Review Date"]="2011-01-24"
df_airline.loc[354,"Review Date"]="2011-01-25"
df_airline.loc[355,"Review Date"]="2011-01-26"
df_airline.loc[356,"Review Date"]="2011-01-27"
df_airline.loc[357,"Review Date"]="2011-01-28"
df_airline.loc[358,"Review Date"]="2011-01-29"
df_airline.loc[359,"Review Date"]="2011-01-30"
df_airline.loc[360,"Review Date"]="2011-01-31"
df_airline.loc[361,"Review Date"]="2011-01-01"
df_airline.loc[362,"Review Date"]="2011-01-02"
df_airline.loc[363,"Review Date"]="2011-01-03"
df_airline.loc[364,"Review Date"]="2011-01-04"
df_airline.loc[365,"Review Date"]="2011-01-05"
df_airline.loc[366,"Review Date"]="2011-01-06"
df_airline.loc[367,"Review Date"]="2011-01-07"
df_airline.loc[368,"Review Date"]="2011-01-08"
df_airline.loc[369,"Review Date"]="2011-01-09"
df_airline.loc[370,"Review Date"]="2011-01-10"
df_airline.loc[371,"Review Date"]="2011-01-11"
df_airline.loc[372,"Review Date"]="2011-01-12"
df_airline.loc[373,"Review Date"]="2011-01-13"
df_airline.loc[374,"Review Date"]="2011-01-14"
df_airline.loc[375,"Review Date"]="2011-01-15"
df_airline.loc[376,"Review Date"]="2011-01-16"
df_airline.loc[377,"Review Date"]="2011-01-17"
df_airline.loc[378,"Review Date"]="2011-01-18"
df_airline.loc[379,"Review Date"]="2011-01-19"
df_airline.loc[380,"Review Date"]="2011-01-20"
df_airline.loc[381,"Review Date"]="2011-01-21"
df_airline.loc[382,"Review Date"]="2011-01-22"
df_airline.loc[383,"Review Date"]="2011-01-23"
df_airline.loc[384,"Review Date"]="2011-01-24"
df_airline.loc[385,"Review Date"]="2011-01-25"
df_airline.loc[386,"Review Date"]="2011-01-26"
df_airline.loc[387,"Review Date"]="2011-01-27"
df_airline.loc[388,"Review Date"]="2011-01-28"
df_airline.loc[389,"Review Date"]="2011-01-29"
df_airline.loc[390,"Review Date"]="2011-01-30"
df_airline.loc[391,"Review Date"]="2011-01-31"
df_airline.loc[392,"Review Date"]="2010-01-01"
df_airline.loc[393,"Review Date"]="2010-01-02"
df_airline.loc[394,"Review Date"]="2010-01-03"
df_airline.loc[395,"Review Date"]="2010-01-04"
df_airline.loc[396,"Review Date"]="2010-01-05"
df_airline.loc[397,"Review Date"]="2010-01-06"
df_airline.loc[398,"Review Date"]="2010-01-07"
df_airline.loc[399,"Review Date"]="2010-01-08"
df_airline.loc[400,"Review Date"]="2010-01-09"
df_airline.loc[401,"Review Date"]="2010-01-10"
df_airline.loc[402,"Review Date"]="2010-01-11"
df_airline.loc[403,"Review Date"]="2010-01-12"
df_airline.loc[404,"Review Date"]="2010-01-13"
df_airline.loc[405,"Review Date"]="2010-01-14"
df_airline.loc[406,"Review Date"]="2010-01-15"
df_airline.loc[407,"Review Date"]="2010-01-16"
df_airline.loc[408,"Review Date"]="2010-01-17"
df_airline.loc[409,"Review Date"]="2010-01-18"
df_airline.loc[410,"Review Date"]="2010-01-19"
df_airline.loc[411,"Review Date"]="2010-01-20"
df_airline.loc[412,"Review Date"]="2010-01-21"
df_airline.loc[413,"Review Date"]="2010-01-22"
df_airline.loc[414,"Review Date"]="2010-01-23"
df_airline.loc[415,"Review Date"]="2010-01-24"
df_airline.loc[416,"Review Date"]="2010-01-25"
df_airline.loc[417,"Review Date"]="2010-01-26"
df_airline.loc[418,"Review Date"]="2010-01-27"
df_airline.loc[419,"Review Date"]="2010-01-28"
df_airline.loc[420,"Review Date"]="2010-01-29"
df_airline.loc[421,"Review Date"]="2010-01-30"
df_airline.loc[422,"Review Date"]="2010-01-31"
df_airline.loc[423,"Review Date"]="2009-01-01"
df_airline.loc[424,"Review Date"]="2009-01-02"
df_airline.loc[425,"Review Date"]="2009-01-03"
df_airline.loc[426,"Review Date"]="2009-01-04"
df_airline.loc[427,"Review Date"]="2009-01-05"
df_airline.loc[428,"Review Date"]="2009-01-06"
df_airline.loc[429,"Review Date"]="2009-01-07"
df_airline.loc[430,"Review Date"]="2009-01-08"
df_airline.loc[431,"Review Date"]="2009-01-09"
df_airline.loc[432,"Review Date"]="2009-01-10"
df_airline.loc[433,"Review Date"]="2009-01-11"
df_airline.loc[434,"Review Date"]="2009-01-12"
df_airline.loc[435,"Review Date"]="2009-01-13"
df_airline.loc[436,"Review Date"]="2009-01-14"
df_airline.loc[437,"Review Date"]="2009-01-15"
df_airline.loc[438,"Review Date"]="2009-01-16"
df_airline.loc[439,"Review Date"]="2009-01-17"
df_airline.loc[440,"Review Date"]="2009-01-18"
df_airline.loc[441,"Review Date"]="2009-01-19"
df_airline.loc[442,"Review Date"]="2009-01-20"
df_airline.loc[443,"Review Date"]="2009-01-21"
df_airline.loc[444,"Review Date"]="2009-01-22"
df_airline.loc[445,"Review Date"]="2009-01-23"
df_airline.loc[446,"Review Date"]="2009-01-24"
df_airline.loc[447,"Review Date"]="2009-01-25"
df_airline.loc[448,"Review Date"]="2009-01-26"
df_airline.loc[449,"Review Date"]="2009-01-27"
df_airline.loc[450,"Review Date"]="2009-01-28"
df_airline.loc[451,"Review Date"]="2009-01-29"
df_airline.loc[452,"Review Date"]="2009-01-30"
df_airline.loc[453,"Review Date"]="2009-01-31"
df_airline.loc[454,"Review Date"]="2008-01-01"
df_airline.loc[455,"Review Date"]="2010-01-02"
df_airline.loc[456,"Review Date"]="2010-01-03"
df_airline.loc[457,"Review Date"]="2010-01-04"
df_airline.loc[458,"Review Date"]="2010-01-05"
df_airline.loc[459,"Review Date"]="2010-01-06"
df_airline.loc[460,"Review Date"]="2010-01-07"
df_airline.loc[461,"Review Date"]="2010-01-08"
df_airline.loc[462,"Review Date"]="2010-01-09"
df_airline.loc[463,"Review Date"]="2010-01-10"
df_airline.loc[464,"Review Date"]="2010-01-11"
df_airline.loc[465,"Review Date"]="2010-01-12"
df_airline.loc[466,"Review Date"]="2010-01-13"
df_airline.loc[467,"Review Date"]="2010-01-14"
df_airline.loc[468,"Review Date"]="2010-01-15"
df_airline.loc[469,"Review Date"]="2010-01-16"
df_airline.loc[470,"Review Date"]="2010-01-17"
df_airline.loc[471,"Review Date"]="2010-01-18"
df_airline.loc[472,"Review Date"]="2010-01-19"
df_airline.loc[473,"Review Date"]="2010-01-20"
df_airline.loc[474,"Review Date"]="2010-01-21"
df_airline.loc[475,"Review Date"]="2010-01-22"
df_airline.loc[476,"Review Date"]="2010-01-23"
df_airline.loc[477,"Review Date"]="2010-01-24"
df_airline.loc[478,"Review Date"]="2010-01-25"
df_airline.loc[479,"Review Date"]="2010-01-26"
df_airline.loc[480,"Review Date"]="2010-01-27"
df_airline.loc[481,"Review Date"]="2010-01-28"
df_airline.loc[482,"Review Date"]="2010-01-29"
df_airline.loc[483,"Review Date"]="2010-01-30"
df_airline.loc[484,"Review Date"]="2010-01-31"
df_airline.loc[485,"Review Date"]="2009-01-01"
df_airline.loc[486,"Review Date"]="2009-01-02"
df_airline.loc[487,"Review Date"]="2009-01-03"
df_airline.loc[488,"Review Date"]="2009-01-04"
df_airline.loc[489,"Review Date"]="2009-01-05"
df_airline.loc[490,"Review Date"]="2009-01-06"
df_airline.loc[491,"Review Date"]="2009-01-07"
df_airline.loc[492,"Review Date"]="2009-01-08"
df_airline.loc[493,"Review Date"]="2009-01-09"
df_airline.loc[494,"Review Date"]="2009-01-10"
df_airline.loc[495,"Review Date"]="2009-01-11"
df_airline.loc[496,"Review Date"]="2009-01-12"
df_airline.loc[497,"Review Date"]="2009-01-13"
df_airline.loc[498,"Review Date"]="2009-01-14"
df_airline.loc[499,"Review Date"]="2009-01-15"
df_airline.loc[500,"Review Date"]="2009-01-16"
df_airline.loc[501,"Review Date"]="2009-01-17"
df_airline.loc[502,"Review Date"]="2009-01-18"
df_airline.loc[503,"Review Date"]="2009-01-19"
df_airline.loc[504,"Review Date"]="2009-01-20"
df_airline.loc[505,"Review Date"]="2009-01-21"
df_airline.loc[506,"Review Date"]="2009-01-22"
df_airline.loc[507,"Review Date"]="2009-01-23"
df_airline.loc[508,"Review Date"]="2009-01-24"
df_airline.loc[509,"Review Date"]="2009-01-25"
df_airline.loc[510,"Review Date"]="2009-01-26"
df_airline.loc[511,"Review Date"]="2009-01-27"
df_airline.loc[512,"Review Date"]="2009-01-28"
df_airline.loc[513,"Review Date"]="2009-01-29"
df_airline.loc[514,"Review Date"]="2009-01-30"
df_airline.loc[515,"Review Date"]="2009-01-31"
df_airline.loc[516,"Review Date"]="2008-01-01"
df_airline.loc[517,"Review Date"]="2008-01-02"
df_airline.loc[518,"Review Date"]="2008-01-03"
df_airline.loc[519,"Review Date"]="2008-01-04"
df_airline.loc[520,"Review Date"]="2008-01-05"
df_airline.loc[521,"Review Date"]="2008-01-06"
df_airline.loc[522,"Review Date"]="2008-01-07"
df_airline.loc[523,"Review Date"]="2008-01-08"
df_airline.loc[524,"Review Date"]="2008-01-09"
df_airline.loc[525,"Review Date"]="2008-01-10"
df_airline.loc[526,"Review Date"]="2008-01-11"
df_airline.loc[527,"Review Date"]="2008-01-12"
df_airline.loc[528,"Review Date"]="2008-01-13"
df_airline.loc[529,"Review Date"]="2008-01-14"
df_airline.loc[530,"Review Date"]="2008-01-15"
df_airline.loc[531,"Review Date"]="2008-01-16"
df_airline.loc[532,"Review Date"]="2008-01-17"
df_airline.loc[533,"Review Date"]="2008-01-18"
df_airline.loc[534,"Review Date"]="2008-01-19"
df_airline.loc[535,"Review Date"]="2008-01-20"
df_airline.loc[536,"Review Date"]="2008-01-21"
df_airline.loc[537,"Review Date"]="2008-01-22"
df_airline.loc[539,"Review Date"]="2008-01-23"
df_airline.loc[540,"Review Date"]="2008-01-24"
df_airline.loc[541,"Review Date"]="2008-01-25"
df_airline.loc[542,"Review Date"]="2008-01-26"
df_airline.loc[543,"Review Date"]="2008-01-27"
df_airline.loc[544,"Review Date"]="2008-01-28"
df_airline.loc[545,"Review Date"]="2008-01-29"
df_airline.loc[546,"Review Date"]="2008-01-30"
df_airline.loc[547,"Review Date"]="2008-01-31"
df_airline.loc[548,"Review Date"]="2007-01-01"
df_airline.loc[549,"Review Date"]="2007-01-02"
df_airline.loc[550,"Review Date"]="2007-01-03"
df_airline.loc[551,"Review Date"]="2007-01-04"
df_airline.loc[552,"Review Date"]="2007-01-05"
df_airline.loc[553,"Review Date"]="2007-01-06"
df_airline.loc[554,"Review Date"]="2007-01-07"
df_airline.loc[555,"Review Date"]="2007-01-08"
df_airline.loc[556,"Review Date"]="2007-01-09"
df_airline.loc[557,"Review Date"]="2007-01-10"
df_airline.loc[558,"Review Date"]="2007-01-11"
df_airline.loc[559,"Review Date"]="2007-01-12"
df_airline.loc[560,"Review Date"]="2007-01-13"
df_airline.loc[561,"Review Date"]="2007-01-14"
df_airline.loc[562,"Review Date"]="2007-01-15"
df_airline.loc[563,"Review Date"]="2007-01-16"
df_airline.loc[564,"Review Date"]="2007-01-17"
df_airline.loc[565,"Review Date"]="2007-01-18"
df_airline.loc[566,"Review Date"]="2007-01-19"
df_airline.loc[567,"Review Date"]="2007-01-20"
df_airline.loc[568,"Review Date"]="2007-01-21"
df_airline.loc[569,"Review Date"]="2007-01-22"
df_airline.loc[570,"Review Date"]="2007-01-23"
df_airline.loc[571,"Review Date"]="2007-01-24"
df_airline.loc[572,"Review Date"]="2007-01-25"
df_airline.loc[573,"Review Date"]="2007-01-26"
df_airline.loc[574,"Review Date"]="2007-01-27"
df_airline.loc[575,"Review Date"]="2007-01-28"
df_airline.loc[576,"Review Date"]="2007-01-29"
df_airline.loc[577,"Review Date"]="2007-01-30"
df_airline.loc[578,"Review Date"]="2007-01-31"
df_airline.loc[579,"Review Date"]="2006-01-01"
df_airline.loc[580,"Review Date"]="2006-01-02"
df_airline.loc[581,"Review Date"]="2006-01-03"
df_airline.loc[582,"Review Date"]="2006-01-04"
df_airline.loc[583,"Review Date"]="2006-01-05"
df_airline.loc[584,"Review Date"]="2006-01-06"
df_airline.loc[585,"Review Date"]="2006-01-07"
df_airline.loc[586,"Review Date"]="2006-01-08"
df_airline.loc[587,"Review Date"]="2006-01-09"
df_airline.loc[588,"Review Date"]="2006-01-10"
df_airline.loc[589,"Review Date"]="2006-01-11"
df_airline.loc[590,"Review Date"]="2006-01-12"
df_airline.loc[591,"Review Date"]="2006-01-13"
df_airline.loc[592,"Review Date"]="2006-01-14"
df_airline.loc[593,"Review Date"]="2006-01-15"
df_airline.loc[594,"Review Date"]="2006-01-16"
df_airline.loc[595,"Review Date"]="2006-01-17"
df_airline.loc[596,"Review Date"]="2006-01-18"
df_airline.loc[597,"Review Date"]="2006-01-19"
df_airline.loc[598,"Review Date"]="2006-01-20"
df_airline.loc[599,"Review Date"]="2006-01-21"
df_airline.loc[600,"Review Date"]="2006-01-22"
df_airline.loc[601,"Review Date"]="2006-01-23"
df_airline.loc[602,"Review Date"]="2006-01-24"
df_airline.loc[603,"Review Date"]="2006-01-25"
df_airline.loc[604,"Review Date"]="2006-01-26"
df_airline.loc[605,"Review Date"]="2006-01-27"
df_airline.loc[606,"Review Date"]="2006-01-28"
df_airline.loc[607,"Review Date"]="2006-01-29"
df_airline.loc[608,"Review Date"]="2006-01-30"
df_airline.loc[609,"Review Date"]="2006-01-31"
df_airline.loc[610,"Review Date"]="2017-03-02"
df_airline.loc[611,"Review Date"]="2017-03-03"
df_airline.loc[612,"Review Date"]="2017-03-04"
df_airline.loc[613,"Review Date"]="2017-03-05"
df_airline.loc[614,"Review Date"]="2017-03-06"
df_airline.loc[615,"Review Date"]="2017-03-07"
df_airline.loc[616,"Review Date"]="2017-03-08"
df_airline.loc[617,"Review Date"]="2017-03-09"
df_airline.loc[618,"Review Date"]="2017-03-10"
df_airline.loc[619,"Review Date"]="2017-03-11"
df_airline.loc[620,"Review Date"]="2017-03-12"
df_airline.loc[621,"Review Date"]="2017-03-13"
df_airline.loc[622,"Review Date"]="2017-03-14"
df_airline.loc[623,"Review Date"]="2017-03-16"
df_airline.loc[624,"Review Date"]="2017-03-17"
df_airline.loc[625,"Review Date"]="2017-03-18"
df_airline.loc[626,"Review Date"]="2017-03-19"
df_airline.loc[627,"Review Date"]="2017-03-20"
df_airline.loc[628,"Review Date"]="2017-03-21"
df_airline.loc[629,"Review Date"]="2017-03-22"
df_airline.loc[630,"Review Date"]="2017-03-23"
df_airline.loc[631,"Review Date"]="2017-03-24"
df_airline.loc[632,"Review Date"]="2017-03-25"
df_airline.loc[633,"Review Date"]="2017-03-26"
df_airline.loc[634,"Review Date"]="2017-03-27"
df_airline.loc[635,"Review Date"]="2017-03-28"
df_airline.loc[636,"Review Date"]="2017-03-29"
df_airline.loc[637,"Review Date"]="2017-03-30"
df_airline.loc[638,"Review Date"]="2017-03-31"
df_airline.loc[639,"Review Date"]="2016-03-03"
df_airline.loc[640,"Review Date"]="2016-03-04"
df_airline.loc[641,"Review Date"]="2016-03-05"
df_airline.loc[642,"Review Date"]="2016-03-06"
df_airline.loc[643,"Review Date"]="2016-03-07"
df_airline.loc[644,"Review Date"]="2016-03-08"
df_airline.loc[645,"Review Date"]="2016-03-09"
df_airline.loc[646,"Review Date"]="2016-03-10"
df_airline.loc[647,"Review Date"]="2016-03-11"
df_airline.loc[648,"Review Date"]="2016-03-12"
df_airline.loc[649,"Review Date"]="2016-03-13"
df_airline.loc[650,"Review Date"]="2016-03-14"
df_airline.loc[651,"Review Date"]="2016-03-15"
df_airline.loc[652,"Review Date"]="2016-03-16"
df_airline.loc[653,"Review Date"]="2016-03-17"
df_airline.loc[654,"Review Date"]="2016-03-18"
df_airline.loc[655,"Review Date"]="2016-03-19"
df_airline.loc[656,"Review Date"]="2016-03-20"
df_airline.loc[657,"Review Date"]="2016-03-21"
df_airline.loc[658,"Review Date"]="2016-03-22"
df_airline.loc[659,"Review Date"]="2016-03-23"
df_airline.loc[660,"Review Date"]="2016-03-24"
df_airline.loc[661,"Review Date"]="2016-03-25"
df_airline.loc[662,"Review Date"]="2016-03-26"
df_airline.loc[663,"Review Date"]="2016-03-27"
df_airline.loc[664,"Review Date"]="2016-03-28"
df_airline.loc[665,"Review Date"]="2016-03-29"
df_airline.loc[666,"Review Date"]="2016-03-30"
df_airline.loc[667,"Review Date"]="2016-03-31"
df_airline.loc[668,"Review Date"]="2015-03-02"
df_airline.loc[669,"Review Date"]="2015-03-03"
df_airline.loc[670,"Review Date"]="2015-03-04"
df_airline.loc[671,"Review Date"]="2015-03-05"
df_airline.loc[672,"Review Date"]="2015-03-06"
df_airline.loc[673,"Review Date"]="2015-03-07"
df_airline.loc[674,"Review Date"]="2015-03-08"
df_airline.loc[675,"Review Date"]="2015-03-09"
df_airline.loc[676,"Review Date"]="2015-03-10"
df_airline.loc[677,"Review Date"]="2015-03-11"
df_airline.loc[678,"Review Date"]="2015-03-12"
df_airline.loc[679,"Review Date"]="2015-03-13"
df_airline.loc[680,"Review Date"]="2015-03-14"
df_airline.loc[681,"Review Date"]="2015-03-15"
df_airline.loc[682,"Review Date"]="2015-03-16"
df_airline.loc[683,"Review Date"]="2015-03-17"
df_airline.loc[684,"Review Date"]="2015-03-18" 
df_airline.loc[685,"Review Date"]="2015-03-19"
df_airline.loc[686,"Review Date"]="2015-03-20"
df_airline.loc[687,"Review Date"]="2015-03-21"
df_airline.loc[688,"Review Date"]="2015-03-22"
df_airline.loc[689,"Review Date"]="2015-03-23"
df_airline.loc[690,"Review Date"]="2015-03-24"
df_airline.loc[691,"Review Date"]="2015-03-35"
df_airline.loc[692,"Review Date"]="2015-03-26"
df_airline.loc[693,"Review Date"]="2015-03-27"
df_airline.loc[694,"Review Date"]="2015-03-28"
df_airline.loc[695,"Review Date"]="2015-03-29"
df_airline.loc[696,"Review Date"]="2015-03-30"
df_airline.loc[697,"Review Date"]="2015-03-31"
df_airline.loc[698,"Review Date"]="2014-03-02"
df_airline.loc[699,"Review Date"]="2014-03-03"
df_airline.loc[700,"Review Date"]="2014-03-04"
df_airline.loc[701,"Review Date"]="2014-03-05"
df_airline.loc[702,"Review Date"]="2014-03-06"
df_airline.loc[703,"Review Date"]="2014-03-07"
df_airline.loc[704,"Review Date"]="2014-03-08"
df_airline.loc[705,"Review Date"]="2014-03-09"
df_airline.loc[706,"Review Date"]="2014-03-10"
df_airline.loc[707,"Review Date"]="2014-03-11"
df_airline.loc[708,"Review Date"]="2014-03-12"
df_airline.loc[709,"Review Date"]="2014-03-13"
df_airline.loc[710,"Review Date"]="2014-03-14"
df_airline.loc[711,"Review Date"]="2014-03-15"
df_airline.loc[712,"Review Date"]="2014-03-16"
df_airline.loc[713,"Review Date"]="2014-03-17"
df_airline.loc[714,"Review Date"]="2014-03-18"
df_airline.loc[715,"Review Date"]="2014-03-19"
df_airline.loc[716,"Review Date"]="2014-03-20"
df_airline.loc[717,"Review Date"]="2014-03-21"
df_airline.loc[718,"Review Date"]="2014-03-22"
df_airline.loc[719,"Review Date"]="2014-03-23"
df_airline.loc[720,"Review Date"]="2014-03-24"
df_airline.loc[721,"Review Date"]="2014-03-25"
df_airline.loc[722,"Review Date"]="2014-03-26"
df_airline.loc[723,"Review Date"]="2014-03-27"
df_airline.loc[724,"Review Date"]="2014-03-28"
df_airline.loc[725,"Review Date"]="2014-03-29"
df_airline.loc[726,"Review Date"]="2014-03-30"
df_airline.loc[727,"Review Date"]="2014-03-31"
df_airline.loc[728,"Review Date"]="2013-03-02"
df_airline.loc[729,"Review Date"]="2013-03-03"
df_airline.loc[730,"Review Date"]="2013-03-04"
df_airline.loc[731,"Review Date"]="2013-03-05"
df_airline.loc[732,"Review Date"]="2013-03-06"
df_airline.loc[734,"Review Date"]="2013-03-07"
df_airline.loc[733,"Review Date"]="2013-03-08"
df_airline.loc[734,"Review Date"]="2013-03-09"
df_airline.loc[735,"Review Date"]="2013-03-10"
df_airline.loc[736,"Review Date"]="2013-03-11"
df_airline.loc[737,"Review Date"]="2013-03-12"
df_airline.loc[738,"Review Date"]="2013-03-13"
df_airline.loc[739,"Review Date"]="2013-03-14"
df_airline.loc[740,"Review Date"]="2013-03-15"
df_airline.loc[741,"Review Date"]="2013-03-16"
df_airline.loc[742,"Review Date"]="2013-03-17"
df_airline.loc[743,"Review Date"]="2013-03-18"
df_airline.loc[744,"Review Date"]="2013-03-19"
df_airline.loc[745,"Review Date"]="2013-03-20"
df_airline.loc[746,"Review Date"]="2013-03-21"
df_airline.loc[747,"Review Date"]="2013-03-22"
df_airline.loc[748,"Review Date"]="2013-03-23"
df_airline.loc[749,"Review Date"]="2013-03-24"
df_airline.loc[750,"Review Date"]="2013-03-25"
df_airline.loc[751,"Review Date"]="2013-03-26"
df_airline.loc[752,"Review Date"]="2013-03-27"
df_airline.loc[753,"Review Date"]="2013-03-28"
df_airline.loc[754,"Review Date"]="2013-03-29"
df_airline.loc[755,"Review Date"]="2013-03-30"
df_airline.loc[756,"Review Date"]="2013-03-31"
df_airline.loc[757,"Review Date"]="2012-03-04"
df_airline.loc[758,"Review Date"]="2012-03-02"
df_airline.loc[759,"Review Date"]="2012-03-03"
df_airline.loc[760,"Review Date"]="2012-03-05"
df_airline.loc[761,"Review Date"]="2012-03-06"
df_airline.loc[762,"Review Date"]="2012-03-07"
df_airline.loc[763,"Review Date"]="2012-03-08"
df_airline.loc[764,"Review Date"]="2012-03-09"
df_airline.loc[765,"Review Date"]="2012-03-10"
df_airline.loc[766,"Review Date"]="2012-03-11"
df_airline.loc[767,"Review Date"]="2012-03-12"
df_airline.loc[768,"Review Date"]="2012-03-13"
df_airline.loc[769,"Review Date"]="2012-03-14"
df_airline.loc[770,"Review Date"]="2012-03-15"
df_airline.loc[771,"Review Date"]="2012-03-16"
df_airline.loc[772,"Review Date"]="2012-03-17"
df_airline.loc[773,"Review Date"]="2012-03-18"
df_airline.loc[774,"Review Date"]="2012-03-19"
df_airline.loc[775,"Review Date"]="2012-03-20"
df_airline.loc[776,"Review Date"]="2012-03-21"
df_airline.loc[777,"Review Date"]="2012-03-22"
df_airline.loc[778,"Review Date"]="2012-03-23"
df_airline.loc[779,"Review Date"]="2012-03-24"
df_airline.loc[780,"Review Date"]="2012-03-25"
df_airline.loc[781,"Review Date"]="2012-03-26"
df_airline.loc[782,"Review Date"]="2012-03-27"
df_airline.loc[783,"Review Date"]="2012-03-28"
df_airline.loc[784,"Review Date"]="2012-03-29"
df_airline.loc[785,"Review Date"]="2012-03-30"
df_airline.loc[786,"Review Date"]="2012-03-31"
df_airline.loc[787,"Review Date"]="2011-03-03"
df_airline.loc[788,"Review Date"]="2011-03-04"
df_airline.loc[789,"Review Date"]="2011-03-05"
df_airline.loc[790,"Review Date"]="2011-03-06"
df_airline.loc[791,"Review Date"]="2011-03-07"
df_airline.loc[792,"Review Date"]="2011-03-08"
df_airline.loc[793,"Review Date"]="2011-03-09"
df_airline.loc[794,"Review Date"]="2011-03-10"
df_airline.loc[795,"Review Date"]="2011-03-11"
df_airline.loc[796,"Review Date"]="2011-03-12"
df_airline.loc[797,"Review Date"]="2011-03-13"
df_airline.loc[798,"Review Date"]="2011-03-14"
df_airline.loc[799,"Review Date"]="2011-03-15"
df_airline.loc[800,"Review Date"]="2011-03-16"

# %% [markdown]
# #### Expanding the 'Rating"

# %%
df_airline.loc[0,"Rating"]="1.11111"
df_airline.loc[1,"Rating"]="1.11112"
df_airline.loc[2,"Rating"]="1.11113"
df_airline.loc[3,"Rating"]="1.11114"
df_airline.loc[4,"Rating"]="1.11115"
df_airline.loc[5,"Rating"]="1.11116"
df_airline.loc[6,"Rating"]="1.11117"
df_airline.loc[7,"Rating"]="1.11118"
df_airline.loc[8,"Rating"]="1.11119"
df_airline.loc[9,"Rating"]="1.11110"
df_airline.loc[10,"Rating"]="1.11111"
df_airline.loc[11,"Rating"]="1.11112"
df_airline.loc[12,"Rating"]="1.11113"
df_airline.loc[13,"Rating"]="1.11114"
df_airline.loc[14,"Rating"]="1.11115"
df_airline.loc[15,"Rating"]="1.11116"
df_airline.loc[16,"Rating"]="1.11117"
df_airline.loc[17,"Rating"]="1.11118"
df_airline.loc[18,"Rating"]="1.11119"
df_airline.loc[19,"Rating"]="1.11120"
df_airline.loc[20,"Rating"]="1.11121"
df_airline.loc[21,"Rating"]="1.11122"
df_airline.loc[22,"Rating"]="1.11123"
df_airline.loc[23,"Rating"]="1.11124"
df_airline.loc[24,"Rating"]="1.11125"
df_airline.loc[25,"Rating"]="1.11126"
df_airline.loc[26,"Rating"]="1.11127"
df_airline.loc[27,"Rating"]="1.11128"
df_airline.loc[28,"Rating"]="1.11129"
df_airline.loc[29,"Rating"]="1.11130"
df_airline.loc[30,"Rating"]="1.11131"
df_airline.loc[31,"Rating"]="1.11132"
df_airline.loc[32,"Rating"]="1.11133"
df_airline.loc[33,"Rating"]="1.11134"
df_airline.loc[34,"Rating"]="1.11135"
df_airline.loc[35,"Rating"]="1.11136"
df_airline.loc[36,"Rating"]="1.11137"
df_airline.loc[37,"Rating"]="1.11138"
df_airline.loc[38,"Rating"]="1.11139"
df_airline.loc[39,"Rating"]="1.11140"
df_airline.loc[40,"Rating"]="1.11141"
df_airline.loc[41,"Rating"]="1.11142"
df_airline.loc[42,"Rating"]="1.11143"
df_airline.loc[43,"Rating"]="1.11144"
df_airline.loc[44,"Rating"]="1.11145"
df_airline.loc[45,"Rating"]="1.11146"
df_airline.loc[46,"Rating"]="1.11147"
df_airline.loc[47,"Rating"]="1.11148"
df_airline.loc[48,"Rating"]="1.11149"
df_airline.loc[49,"Rating"]="1.11150"
df_airline.loc[50,"Rating"]="1.11151"
df_airline.loc[51,"Rating"]="1.11152"
df_airline.loc[52,"Rating"]="1.11153"
df_airline.loc[53,"Rating"]="1.11154"
df_airline.loc[54,"Rating"]="1.11155"
df_airline.loc[55,"Rating"]="1.11156"
df_airline.loc[56,"Rating"]="1.11157"
df_airline.loc[57,"Rating"]="1.11158"
df_airline.loc[58,"Rating"]="1.11159"
df_airline.loc[59,"Rating"]="1.11160"
df_airline.loc[60,"Rating"]="1.11161"
df_airline.loc[61,"Rating"]="1.11162"
df_airline.loc[62,"Rating"]="1.11163"
df_airline.loc[63,"Rating"]="1.11164"
df_airline.loc[64,"Rating"]="1.11165"
df_airline.loc[65,"Rating"]="1.11166"
df_airline.loc[66,"Rating"]="1.11167"
df_airline.loc[67,"Rating"]="1.11168"
df_airline.loc[68,"Rating"]="1.11169"
df_airline.loc[69,"Rating"]="1.11170"
df_airline.loc[70,"Rating"]="1.11171"
df_airline.loc[71,"Rating"]="1.11172"
df_airline.loc[72,"Rating"]="1.11173"
df_airline.loc[73,"Rating"]="1.11174"
df_airline.loc[74,"Rating"]="1.11175"
df_airline.loc[75,"Rating"]="1.11176"
df_airline.loc[76,"Rating"]="1.11177"
df_airline.loc[77,"Rating"]="1.11178"
df_airline.loc[78,"Rating"]="1.11179"
df_airline.loc[79,"Rating"]="1.11180"
df_airline.loc[80,"Rating"]="1.11181"
df_airline.loc[81,"Rating"]="1.11182"
df_airline.loc[82,"Rating"]="1.11183"
df_airline.loc[83,"Rating"]="1.11184"
df_airline.loc[84,"Rating"]="1.11185"
df_airline.loc[85,"Rating"]="1.11186"
df_airline.loc[86,"Rating"]="1.11187"
df_airline.loc[87,"Rating"]="1.11188"
df_airline.loc[88,"Rating"]="1.11189"
df_airline.loc[89,"Rating"]="1.11190"
df_airline.loc[90,"Rating"]="1.11191"
df_airline.loc[91,"Rating"]="1.11192"
df_airline.loc[92,"Rating"]="1.11193"
df_airline.loc[93,"Rating"]="1.11194"
df_airline.loc[94,"Rating"]="1.11195"
df_airline.loc[95,"Rating"]="1.11196"
df_airline.loc[96,"Rating"]="1.11197"
df_airline.loc[97,"Rating"]="1.11198"
df_airline.loc[98,"Rating"]="1.11199"
df_airline.loc[99,"Rating"]="1.11200"
df_airline.loc[100,"Rating"]="1.11201"
df_airline.loc[101,"Rating"]="1.11202"
df_airline.loc[102,"Rating"]="1.11203"
df_airline.loc[103,"Rating"]="1.11204"
df_airline.loc[104,"Rating"]="1.11205"
df_airline.loc[105,"Rating"]="1.11206"
df_airline.loc[106,"Rating"]="1.11207"
df_airline.loc[107,"Rating"]="1.11208"
df_airline.loc[108,"Rating"]="1.11209"
df_airline.loc[109,"Rating"]="1.11210"
df_airline.loc[110,"Rating"]="1.11211"
df_airline.loc[111,"Rating"]="1.11212"
df_airline.loc[112,"Rating"]="1.11213"
df_airline.loc[113,"Rating"]="1.11214"
df_airline.loc[114,"Rating"]="1.11215"
df_airline.loc[115,"Rating"]="1.11216"
df_airline.loc[116,"Rating"]="1.11217"
df_airline.loc[117,"Rating"]="1.11218"
df_airline.loc[118,"Rating"]="1.11219"
df_airline.loc[119,"Rating"]="1.11220"
df_airline.loc[120,"Rating"]="1.11221"
df_airline.loc[121,"Rating"]="1.11222"
df_airline.loc[122,"Rating"]="1.11223"
df_airline.loc[123,"Rating"]="1.11224"
df_airline.loc[124,"Rating"]="1.11225"
df_airline.loc[125,"Rating"]="1.11226"
df_airline.loc[126,"Rating"]="1.11227"
df_airline.loc[127,"Rating"]="1.11228"
df_airline.loc[128,"Rating"]="1.11229"
df_airline.loc[129,"Rating"]="1.11230"
df_airline.loc[130,"Rating"]="1.11231"
df_airline.loc[131,"Rating"]="1.11230"
df_airline.loc[132,"Rating"]="1.11232"
df_airline.loc[133,"Rating"]="1.11233"
df_airline.loc[134,"Rating"]="1.11234"
df_airline.loc[135,"Rating"]="1.11235"
df_airline.loc[136,"Rating"]="1.11236"
df_airline.loc[137,"Rating"]="1.11237"
df_airline.loc[138,"Rating"]="1.11238"
df_airline.loc[139,"Rating"]="1.11239"
df_airline.loc[140,"Rating"]="1.11240"
df_airline.loc[141,"Rating"]="1.11241"
df_airline.loc[142,"Rating"]="1.11242"
df_airline.loc[143,"Rating"]="1.11243"
df_airline.loc[144,"Rating"]="1.11244"
df_airline.loc[145,"Rating"]="1.11245"
df_airline.loc[146,"Rating"]="1.11246"
df_airline.loc[147,"Rating"]="1.11247"
df_airline.loc[148,"Rating"]="1.11248"
df_airline.loc[149,"Rating"]="1.11249"
df_airline.loc[150,"Rating"]="1.11250"
df_airline.loc[151,"Rating"]="2.11111"
df_airline.loc[152,"Rating"]="2.11112"
df_airline.loc[153,"Rating"]="2.11113"
df_airline.loc[154,"Rating"]="2.11114"
df_airline.loc[155,"Rating"]="2.11115"
df_airline.loc[156,"Rating"]="2.11116"
df_airline.loc[157,"Rating"]="2.11117"
df_airline.loc[158,"Rating"]="2.11118"
df_airline.loc[159,"Rating"]="2.11119"
df_airline.loc[160,"Rating"]="2.11110"
df_airline.loc[161,"Rating"]="2.11111"
df_airline.loc[162,"Rating"]="2.11112"
df_airline.loc[163,"Rating"]="2.11113"
df_airline.loc[164,"Rating"]="2.11114"
df_airline.loc[165,"Rating"]="2.11115"
df_airline.loc[166,"Rating"]="2.11116"
df_airline.loc[167,"Rating"]="2.11117"
df_airline.loc[168,"Rating"]="2.11118"
df_airline.loc[169,"Rating"]="2.11119"
df_airline.loc[171,"Rating"]="2.11120"
df_airline.loc[172,"Rating"]="2.11121"
df_airline.loc[173,"Rating"]="2.11122"
df_airline.loc[174,"Rating"]="2.11123"
df_airline.loc[175,"Rating"]="2.11124"
df_airline.loc[176,"Rating"]="2.11125"
df_airline.loc[177,"Rating"]="2.11126"
df_airline.loc[178,"Rating"]="2.11127"
df_airline.loc[179,"Rating"]="2.11128"
df_airline.loc[180,"Rating"]="2.11129"
df_airline.loc[181,"Rating"]="2.11130"
df_airline.loc[182,"Rating"]="2.11131"
df_airline.loc[183,"Rating"]="2.11132"
df_airline.loc[184,"Rating"]="2.11133"
df_airline.loc[185,"Rating"]="2.11134"
df_airline.loc[186,"Rating"]="2.11135"
df_airline.loc[187,"Rating"]="2.11136"
df_airline.loc[188,"Rating"]="2.11137"
df_airline.loc[189,"Rating"]="2.11138"
df_airline.loc[190,"Rating"]="2.11139"
df_airline.loc[191,"Rating"]="2.11140"
df_airline.loc[192,"Rating"]="2.11141"
df_airline.loc[193,"Rating"]="1.11142"
df_airline.loc[194,"Rating"]="1.11143"
df_airline.loc[195,"Rating"]="2.11144"
df_airline.loc[196,"Rating"]="2.11145"
df_airline.loc[197,"Rating"]="2.11146"
df_airline.loc[198,"Rating"]="2.11147"
df_airline.loc[199,"Rating"]="2.11148"
df_airline.loc[200,"Rating"]="2.11149"
df_airline.loc[201,"Rating"]="2.11150"
df_airline.loc[202,"Rating"]="2.11151"
df_airline.loc[203,"Rating"]="2.11152"
df_airline.loc[204,"Rating"]="2.11153"
df_airline.loc[205,"Rating"]="2.11154"
df_airline.loc[206,"Rating"]="2.11155"
df_airline.loc[207,"Rating"]="2.11156"
df_airline.loc[208,"Rating"]="2.11157"
df_airline.loc[209,"Rating"]="2.11158"
df_airline.loc[210,"Rating"]="2.11159"
df_airline.loc[211,"Rating"]="2.11160"
df_airline.loc[212,"Rating"]="2.11161"
df_airline.loc[213,"Rating"]="2.11162"
df_airline.loc[214,"Rating"]="2.11163"
df_airline.loc[215,"Rating"]="2.11164"
df_airline.loc[216,"Rating"]="2.11165"
df_airline.loc[217,"Rating"]="2.11166"
df_airline.loc[218,"Rating"]="2.11167"
df_airline.loc[219,"Rating"]="2.11168"
df_airline.loc[220,"Rating"]="2.11169"
df_airline.loc[221,"Rating"]="2.11170"
df_airline.loc[222,"Rating"]="2.11171"
df_airline.loc[223,"Rating"]="2.11172"
df_airline.loc[224,"Rating"]="2.11173"
df_airline.loc[225,"Rating"]="2.11174"
df_airline.loc[226,"Rating"]="2.11175"
df_airline.loc[227,"Rating"]="2.11176"
df_airline.loc[228,"Rating"]="2.11177"
df_airline.loc[229,"Rating"]="2.11178"
df_airline.loc[230,"Rating"]="2.11179"
df_airline.loc[231,"Rating"]="2.11180"
df_airline.loc[232,"Rating"]="2.11181"
df_airline.loc[233,"Rating"]="2.11182"
df_airline.loc[234,"Rating"]="2.11183"
df_airline.loc[235,"Rating"]="2.11184"
df_airline.loc[236,"Rating"]="2.11185"
df_airline.loc[237,"Rating"]="2.11186"
df_airline.loc[238,"Rating"]="2.11187"
df_airline.loc[239,"Rating"]="2.11188"
df_airline.loc[240,"Rating"]="2.11189"
df_airline.loc[242,"Rating"]="2.11190"
df_airline.loc[243,"Rating"]="2.11191"
df_airline.loc[244,"Rating"]="2.11192"
df_airline.loc[245,"Rating"]="2.11193"
df_airline.loc[246,"Rating"]="2.11194"
df_airline.loc[247,"Rating"]="2.11195"
df_airline.loc[248,"Rating"]="2.11196"
df_airline.loc[249,"Rating"]="2.11197"
df_airline.loc[250,"Rating"]="2.11198"
df_airline.loc[251,"Rating"]="2.11199"
df_airline.loc[252,"Rating"]="2.11200"
df_airline.loc[253,"Rating"]="2.11201"
df_airline.loc[254,"Rating"]="2.11202"
df_airline.loc[255,"Rating"]="2.11203"
df_airline.loc[256,"Rating"]="2.11204"
df_airline.loc[257,"Rating"]="2.11205"
df_airline.loc[257,"Rating"]="2.11206"
df_airline.loc[260,"Rating"]="2.11207"
df_airline.loc[262,"Rating"]="2.11208"
df_airline.loc[263,"Rating"]="2.11209"
df_airline.loc[264,"Rating"]="2.11210"
df_airline.loc[265,"Rating"]="2.11211"
df_airline.loc[266,"Rating"]="2.11212"
df_airline.loc[267,"Rating"]="2.11213"
df_airline.loc[268,"Rating"]="2.11214"
df_airline.loc[269,"Rating"]="2.11215"
df_airline.loc[270,"Rating"]="2.11216"
df_airline.loc[271,"Rating"]="2.11217"
df_airline.loc[272,"Rating"]="2.11218"
df_airline.loc[273,"Rating"]="2.11219"
df_airline.loc[274,"Rating"]="2.11220"
df_airline.loc[275,"Rating"]="2.11221"
df_airline.loc[276,"Rating"]="2.11222"
df_airline.loc[277,"Rating"]="2.11223"
df_airline.loc[278,"Rating"]="2.11224"
df_airline.loc[279,"Rating"]="2.11225"
df_airline.loc[280,"Rating"]="2.11226"
df_airline.loc[281,"Rating"]="2.11227"
df_airline.loc[282,"Rating"]="2.11228"
df_airline.loc[283,"Rating"]="2.11229"
df_airline.loc[284,"Rating"]="2.11230"
df_airline.loc[285,"Rating"]="2.11231"
df_airline.loc[286,"Rating"]="2.11230"
df_airline.loc[287,"Rating"]="2.11232"
df_airline.loc[288,"Rating"]="2.11233"
df_airline.loc[289,"Rating"]="2.11234"
df_airline.loc[290,"Rating"]="2.11235"
df_airline.loc[291,"Rating"]="2.11236"
df_airline.loc[292,"Rating"]="2.11237"
df_airline.loc[293,"Rating"]="2.11238"
df_airline.loc[294,"Rating"]="2.11239"
df_airline.loc[295,"Rating"]="2.11240"
df_airline.loc[296,"Rating"]="2.11241"
df_airline.loc[297,"Rating"]="2.11242"
df_airline.loc[298,"Rating"]="2.11243"
df_airline.loc[299,"Rating"]="2.11244"
df_airline.loc[301,"Rating"]="2.11245"
df_airline.loc[302,"Rating"]="2.11246"
df_airline.loc[303,"Rating"]="2.11247"
df_airline.loc[304,"Rating"]="2.11248"
df_airline.loc[305,"Rating"]="2.11249"
df_airline.loc[306,"Rating"]="2.11250"
df_airline.loc[307,"Rating"]="3.11111"
df_airline.loc[308,"Rating"]="3.11112"
df_airline.loc[309,"Rating"]="3.11113"
df_airline.loc[310,"Rating"]="3.11114"
df_airline.loc[311,"Rating"]="3.11115"
df_airline.loc[312,"Rating"]="3.11116"
df_airline.loc[313,"Rating"]="3.11117"
df_airline.loc[314,"Rating"]="3.11118"
df_airline.loc[315,"Rating"]="3.11119"
df_airline.loc[316,"Rating"]="3.11110"
df_airline.loc[317,"Rating"]="3.11111"
df_airline.loc[318,"Rating"]="3.11112"
df_airline.loc[319,"Rating"]="3.11113"
df_airline.loc[320,"Rating"]="2.11114"
df_airline.loc[321,"Rating"]="3.11115"
df_airline.loc[322,"Rating"]="3.11116"
df_airline.loc[323,"Rating"]="3.11117"
df_airline.loc[324,"Rating"]="3.11118"
df_airline.loc[325,"Rating"]="3.11119"
df_airline.loc[326,"Rating"]="3.11120"
df_airline.loc[327,"Rating"]="3.11121"
df_airline.loc[328,"Rating"]="3.11122"
df_airline.loc[329,"Rating"]="3.11123"
df_airline.loc[330,"Rating"]="3.11124"
df_airline.loc[331,"Rating"]="3.11125"
df_airline.loc[332,"Rating"]="3.11126"
df_airline.loc[333,"Rating"]="3.11127"
df_airline.loc[334,"Rating"]="3.11128"
df_airline.loc[335,"Rating"]="3.11129"
df_airline.loc[336,"Rating"]="3.11130"
df_airline.loc[337,"Rating"]="3.11131"
df_airline.loc[338,"Rating"]="3.11132"
df_airline.loc[339,"Rating"]="3.11133"
df_airline.loc[340,"Rating"]="3.11134"
df_airline.loc[341,"Rating"]="3.11135"
df_airline.loc[342,"Rating"]="3.11136"
df_airline.loc[343,"Rating"]="3.11137"
df_airline.loc[344,"Rating"]="3.11138"
df_airline.loc[346,"Rating"]="3.11139"
df_airline.loc[347,"Rating"]="3.11140"
df_airline.loc[348,"Rating"]="3.11141"
df_airline.loc[349,"Rating"]="3.11142"
df_airline.loc[350,"Rating"]="3.11143"
df_airline.loc[351,"Rating"]="3.11144"
df_airline.loc[352,"Rating"]="3.11145"
df_airline.loc[353,"Rating"]="3.11146"
df_airline.loc[354,"Rating"]="3.11147"
df_airline.loc[355,"Rating"]="3.11148"
df_airline.loc[356,"Rating"]="3.11149"
df_airline.loc[357,"Rating"]="3.11150"
df_airline.loc[358,"Rating"]="3.11151"
df_airline.loc[359,"Rating"]="3.11152"
df_airline.loc[360,"Rating"]="3.11153"
df_airline.loc[361,"Rating"]="3.11154"
df_airline.loc[362,"Rating"]="3.11155"
df_airline.loc[363,"Rating"]="3.11156"
df_airline.loc[364,"Rating"]="3.11157"
df_airline.loc[365,"Rating"]="3.11158"
df_airline.loc[366,"Rating"]="3.11159"
df_airline.loc[367,"Rating"]="3.11160"
df_airline.loc[368,"Rating"]="3.11161"
df_airline.loc[369,"Rating"]="3.11162"
df_airline.loc[370,"Rating"]="3.11163"
df_airline.loc[371,"Rating"]="3.11164"
df_airline.loc[372,"Rating"]="3.11165"
df_airline.loc[373,"Rating"]="3.11166"
df_airline.loc[374,"Rating"]="3.11167"
df_airline.loc[375,"Rating"]="3.11168"
df_airline.loc[376,"Rating"]="3.11169"
df_airline.loc[377,"Rating"]="3.11170"
df_airline.loc[378,"Rating"]="3.11171"
df_airline.loc[379,"Rating"]="3.11172"
df_airline.loc[380,"Rating"]="3.11173"
df_airline.loc[381,"Rating"]="3.11174"
df_airline.loc[382,"Rating"]="3.11175"
df_airline.loc[383,"Rating"]="3.11176"
df_airline.loc[384,"Rating"]="3.11177"
df_airline.loc[385,"Rating"]="3.11178"
df_airline.loc[386,"Rating"]="3.11179"
df_airline.loc[387,"Rating"]="3.11180"
df_airline.loc[388,"Rating"]="3.11181"
df_airline.loc[389,"Rating"]="3.11182"
df_airline.loc[390,"Rating"]="3.11183"
df_airline.loc[391,"Rating"]="3.11184"
df_airline.loc[392,"Rating"]="3.11185"
df_airline.loc[393,"Rating"]="3.11186"
df_airline.loc[394,"Rating"]="3.11187"
df_airline.loc[395,"Rating"]="3.11188"
df_airline.loc[396,"Rating"]="3.11189"
df_airline.loc[397,"Rating"]="3.11190"
df_airline.loc[398,"Rating"]="3.11191"
df_airline.loc[399,"Rating"]="3.11192"
df_airline.loc[400,"Rating"]="3.11193"
df_airline.loc[401,"Rating"]="3.11194"
df_airline.loc[402,"Rating"]="3.11195"
df_airline.loc[403,"Rating"]="3.11196"
df_airline.loc[404,"Rating"]="3.11197"
df_airline.loc[405,"Rating"]="3.11198"
df_airline.loc[406,"Rating"]="3.11199"
df_airline.loc[407,"Rating"]="3.11200"
df_airline.loc[408,"Rating"]="3.11201"
df_airline.loc[409,"Rating"]="3.11202"
df_airline.loc[410,"Rating"]="3.11203"
df_airline.loc[411,"Rating"]="3.11204"
df_airline.loc[412,"Rating"]="3.11205"
df_airline.loc[413,"Rating"]="3.11206"
df_airline.loc[414,"Rating"]="3.11207"
df_airline.loc[415,"Rating"]="3.11208"
df_airline.loc[416,"Rating"]="3.11209"
df_airline.loc[417,"Rating"]="3.11210"
df_airline.loc[418,"Rating"]="3.11211"
df_airline.loc[419,"Rating"]="3.11212"
df_airline.loc[420,"Rating"]="3.11213"
df_airline.loc[421,"Rating"]="3.11214"
df_airline.loc[422,"Rating"]="3.11215"
df_airline.loc[423,"Rating"]="3.11216"
df_airline.loc[424,"Rating"]="3.11217"
df_airline.loc[425,"Rating"]="3.11218"
df_airline.loc[426,"Rating"]="3.11219"
df_airline.loc[427,"Rating"]="3.11220"
df_airline.loc[428,"Rating"]="3.11221"
df_airline.loc[429,"Rating"]="3.11222"
df_airline.loc[430,"Rating"]="3.11223"
df_airline.loc[431,"Rating"]="3.11224"
df_airline.loc[432,"Rating"]="3.11225"
df_airline.loc[433,"Rating"]="3.11226"
df_airline.loc[434,"Rating"]="3.11227"
df_airline.loc[435,"Rating"]="3.11228"
df_airline.loc[436,"Rating"]="3.11229"
df_airline.loc[437,"Rating"]="3.11230"
df_airline.loc[438,"Rating"]="3.11231"
df_airline.loc[439,"Rating"]="3.11230"
df_airline.loc[440,"Rating"]="3.11232"
df_airline.loc[441,"Rating"]="3.11233"
df_airline.loc[442,"Rating"]="3.11234"
df_airline.loc[443,"Rating"]="3.11235"
df_airline.loc[444,"Rating"]="3.11236"
df_airline.loc[445,"Rating"]="3.11237"
df_airline.loc[446,"Rating"]="3.11238"
df_airline.loc[447,"Rating"]="3.11239"
df_airline.loc[448,"Rating"]="3.11240"
df_airline.loc[449,"Rating"]="3.11241"
df_airline.loc[450,"Rating"]="3.11242"
df_airline.loc[451,"Rating"]="3.11243"
df_airline.loc[452,"Rating"]="3.11244"
df_airline.loc[453,"Rating"]="3.11245"
df_airline.loc[454,"Rating"]="3.11246"
df_airline.loc[455,"Rating"]="3.11247"
df_airline.loc[456,"Rating"]="3.11248"
df_airline.loc[457,"Rating"]="3.11249"
df_airline.loc[458,"Rating"]="3.11250"
df_airline.loc[459,"Rating"]="4.11111"
df_airline.loc[460,"Rating"]="4.11112"
df_airline.loc[461,"Rating"]="4.11113"
df_airline.loc[462,"Rating"]="4.11114"
df_airline.loc[463,"Rating"]="4.11115"
df_airline.loc[464,"Rating"]="4.11116"
df_airline.loc[465,"Rating"]="4.11117"
df_airline.loc[466,"Rating"]="4.11118"
df_airline.loc[467,"Rating"]="4.11119"
df_airline.loc[468,"Rating"]="4.11110"
df_airline.loc[469,"Rating"]="4.11111"
df_airline.loc[470,"Rating"]="4.11112"
df_airline.loc[471,"Rating"]="4.11113"
df_airline.loc[472,"Rating"]="4.11114"
df_airline.loc[473,"Rating"]="4.11115"
df_airline.loc[474,"Rating"]="4.11116"
df_airline.loc[475,"Rating"]="4.11117"
df_airline.loc[476,"Rating"]="4.11118"
df_airline.loc[477,"Rating"]="4.11119"
df_airline.loc[478,"Rating"]="4.11120"
df_airline.loc[479,"Rating"]="4.11121"
df_airline.loc[480,"Rating"]="4.11122"
df_airline.loc[481,"Rating"]="4.11123"
df_airline.loc[482,"Rating"]="4.11124"
df_airline.loc[483,"Rating"]="4.11125"
df_airline.loc[484,"Rating"]="4.11126"
df_airline.loc[485,"Rating"]="4.11127"
df_airline.loc[486,"Rating"]="4.11128"
df_airline.loc[487,"Rating"]="4.11129"
df_airline.loc[488,"Rating"]="4.11130"
df_airline.loc[489,"Rating"]="4.11131"
df_airline.loc[490,"Rating"]="4.11132"
df_airline.loc[491,"Rating"]="4.11133"
df_airline.loc[492,"Rating"]="4.11134"
df_airline.loc[493,"Rating"]="4.11135"
df_airline.loc[494,"Rating"]="4.11136"
df_airline.loc[495,"Rating"]="4.11137"
df_airline.loc[496,"Rating"]="4.11138"
df_airline.loc[497,"Rating"]="4.11139"
df_airline.loc[498,"Rating"]="4.11140"
df_airline.loc[499,"Rating"]="4.11141"
df_airline.loc[500,"Rating"]="4.11142"
df_airline.loc[501,"Rating"]="4.11143"
df_airline.loc[502,"Rating"]="4.11144"
df_airline.loc[503,"Rating"]="4.11145"
df_airline.loc[504,"Rating"]="4.11146"
df_airline.loc[505,"Rating"]="4.11147"
df_airline.loc[506,"Rating"]="4.11148"
df_airline.loc[507,"Rating"]="4.11149"
df_airline.loc[508,"Rating"]="4.11150"
df_airline.loc[509,"Rating"]="4.11151"
df_airline.loc[510,"Rating"]="4.11152"
df_airline.loc[511,"Rating"]="4.11153"
df_airline.loc[512,"Rating"]="4.11154"
df_airline.loc[513,"Rating"]="4.11155"
df_airline.loc[514,"Rating"]="4.11156"
df_airline.loc[515,"Rating"]="4.11157"
df_airline.loc[516,"Rating"]="4.11158"
df_airline.loc[517,"Rating"]="4.11159"
df_airline.loc[518,"Rating"]="4.11160"
df_airline.loc[519,"Rating"]="4.11161"
df_airline.loc[520,"Rating"]="4.11162"
df_airline.loc[521,"Rating"]="4.11163"
df_airline.loc[522,"Rating"]="4.11164"
df_airline.loc[523,"Rating"]="4.11165"
df_airline.loc[524,"Rating"]="4.11166"
df_airline.loc[525,"Rating"]="4.11167"
df_airline.loc[526,"Rating"]="4.11168"
df_airline.loc[527,"Rating"]="4.11169"
df_airline.loc[528,"Rating"]="4.11170"
df_airline.loc[529,"Rating"]="4.11171"
df_airline.loc[530,"Rating"]="4.11172"
df_airline.loc[531,"Rating"]="4.11173"
df_airline.loc[532,"Rating"]="4.11174"
df_airline.loc[533,"Rating"]="4.11175"
df_airline.loc[534,"Rating"]="4.11176"
df_airline.loc[535,"Rating"]="4.11177"
df_airline.loc[536,"Rating"]="4.11178"
df_airline.loc[537,"Rating"]="4.11179"
df_airline.loc[539,"Rating"]="4.11180"
df_airline.loc[540,"Rating"]="4.11181"
df_airline.loc[541,"Rating"]="4.11182"
df_airline.loc[542,"Rating"]="4.11183"
df_airline.loc[543,"Rating"]="4.11184"
df_airline.loc[544,"Rating"]="4.11185"
df_airline.loc[545,"Rating"]="4.11186"
df_airline.loc[546,"Rating"]="4.11187"
df_airline.loc[547,"Rating"]="4.11188"
df_airline.loc[548,"Rating"]="4.11189"
df_airline.loc[549,"Rating"]="4.11190"
df_airline.loc[550,"Rating"]="4.11191"
df_airline.loc[551,"Rating"]="4.11192"
df_airline.loc[552,"Rating"]="4.11193"
df_airline.loc[553,"Rating"]="4.11194"
df_airline.loc[554,"Rating"]="4.11195"
df_airline.loc[555,"Rating"]="4.11196"
df_airline.loc[556,"Rating"]="4.11197"
df_airline.loc[557,"Rating"]="4.11198"
df_airline.loc[558,"Rating"]="4.11199"
df_airline.loc[559,"Rating"]="4.11200"
df_airline.loc[560,"Rating"]="4.11201"
df_airline.loc[561,"Rating"]="4.11202"
df_airline.loc[562,"Rating"]="4.11203"
df_airline.loc[563,"Rating"]="4.11204"
df_airline.loc[564,"Rating"]="4.11205"
df_airline.loc[565,"Rating"]="4.11206"
df_airline.loc[566,"Rating"]="4.11207"
df_airline.loc[567,"Rating"]="4.11208"
df_airline.loc[568,"Rating"]="4.11209"
df_airline.loc[569,"Rating"]="4.11210"
df_airline.loc[570,"Rating"]="4.11211"
df_airline.loc[571,"Rating"]="4.11212"
df_airline.loc[572,"Rating"]="4.11213"
df_airline.loc[573,"Rating"]="4.11214"
df_airline.loc[574,"Rating"]="4.11215"
df_airline.loc[575,"Rating"]="4.11216"
df_airline.loc[576,"Rating"]="4.11217"
df_airline.loc[577,"Rating"]="4.11218"
df_airline.loc[578,"Rating"]="4.11219"
df_airline.loc[579,"Rating"]="4.11220"
df_airline.loc[580,"Rating"]="4.11221"
df_airline.loc[581,"Rating"]="4.11222"
df_airline.loc[582,"Rating"]="4.11223"
df_airline.loc[583,"Rating"]="4.11224"
df_airline.loc[584,"Rating"]="4.11225"
df_airline.loc[585,"Rating"]="4.11226"
df_airline.loc[586,"Rating"]="4.11227"
df_airline.loc[587,"Rating"]="4.11228"
df_airline.loc[588,"Rating"]="4.11229"
df_airline.loc[589,"Rating"]="4.11230"
df_airline.loc[590,"Rating"]="4.11231"
df_airline.loc[591,"Rating"]="4.11230"
df_airline.loc[592,"Rating"]="4.11232"
df_airline.loc[593,"Rating"]="4.11233"
df_airline.loc[594,"Rating"]="4.11234"
df_airline.loc[595,"Rating"]="4.11235"
df_airline.loc[596,"Rating"]="4.11236"
df_airline.loc[597,"Rating"]="4.11237"
df_airline.loc[598,"Rating"]="4.11238"
df_airline.loc[599,"Rating"]="4.11239"
df_airline.loc[600,"Rating"]="4.11240"
df_airline.loc[601,"Rating"]="4.11241"
df_airline.loc[602,"Rating"]="4.11242"
df_airline.loc[603,"Rating"]="4.11243"
df_airline.loc[604,"Rating"]="4.11244"
df_airline.loc[605,"Rating"]="4.11245"
df_airline.loc[606,"Rating"]="4.11246"
df_airline.loc[607,"Rating"]="4.11247"
df_airline.loc[608,"Rating"]="4.11248"
df_airline.loc[609,"Rating"]="4.11249"
df_airline.loc[610,"Rating"]="4.11250"
df_airline.loc[611,"Rating"]="5.11111"
df_airline.loc[612,"Rating"]="5.11112"
df_airline.loc[613,"Rating"]="5.11113"
df_airline.loc[614,"Rating"]="5.11114"
df_airline.loc[615,"Rating"]="5.11115"
df_airline.loc[616,"Rating"]="5.11116"
df_airline.loc[617,"Rating"]="5.11117"
df_airline.loc[618,"Rating"]="5.11118"
df_airline.loc[619,"Rating"]="5.11119"
df_airline.loc[620,"Rating"]="5.11110"
df_airline.loc[621,"Rating"]="5.11111"
df_airline.loc[622,"Rating"]="5.11112"
df_airline.loc[623,"Rating"]="5.11113"
df_airline.loc[624,"Rating"]="5.11114"
df_airline.loc[625,"Rating"]="5.11115"
df_airline.loc[626,"Rating"]="5.11116"
df_airline.loc[627,"Rating"]="5.11117"
df_airline.loc[628,"Rating"]="5.11118"
df_airline.loc[629,"Rating"]="5.11119"
df_airline.loc[630,"Rating"]="5.11120"
df_airline.loc[631,"Rating"]="5.11121"
df_airline.loc[632,"Rating"]="5.11122"
df_airline.loc[633,"Rating"]="5.11123"
df_airline.loc[634,"Rating"]="5.11124"
df_airline.loc[635,"Rating"]="5.11125"
df_airline.loc[636,"Rating"]="5.11126"
df_airline.loc[637,"Rating"]="5.11127"
df_airline.loc[638,"Rating"]="5.11128"
df_airline.loc[639,"Rating"]="5.11129"
df_airline.loc[640,"Rating"]="5.11130"
df_airline.loc[641,"Rating"]="5.11131"
df_airline.loc[642,"Rating"]="5.11132"
df_airline.loc[643,"Rating"]="5.11133"
df_airline.loc[644,"Rating"]="5.11134"
df_airline.loc[645,"Rating"]="5.11135"
df_airline.loc[646,"Rating"]="5.11136"
df_airline.loc[647,"Rating"]="5.11137"
df_airline.loc[648,"Rating"]="5.11138"
df_airline.loc[649,"Rating"]="5.11139"
df_airline.loc[650,"Rating"]="5.11140"
df_airline.loc[651,"Rating"]="5.11141"
df_airline.loc[652,"Rating"]="5.11142"
df_airline.loc[653,"Rating"]="5.11143"
df_airline.loc[654,"Rating"]="5.11144"
df_airline.loc[655,"Rating"]="5.11145"
df_airline.loc[656,"Rating"]="5.11146"
df_airline.loc[657,"Rating"]="5.11147"
df_airline.loc[658,"Rating"]="5.11148"
df_airline.loc[659,"Rating"]="5.11149"
df_airline.loc[660,"Rating"]="5.11150"
df_airline.loc[661,"Rating"]="5.11151"
df_airline.loc[662,"Rating"]="5.11152"
df_airline.loc[663,"Rating"]="5.11153"
df_airline.loc[664,"Rating"]="5.11154"
df_airline.loc[665,"Rating"]="5.11155"
df_airline.loc[666,"Rating"]="5.11156"
df_airline.loc[667,"Rating"]="5.11157"
df_airline.loc[668,"Rating"]="5.11158"
df_airline.loc[669,"Rating"]="5.11159"
df_airline.loc[670,"Rating"]="5.11160"
df_airline.loc[671,"Rating"]="5.11161"
df_airline.loc[672,"Rating"]="5.11162"
df_airline.loc[673,"Rating"]="5.11163"
df_airline.loc[674,"Rating"]="5.11164"
df_airline.loc[675,"Rating"]="5.11165"
df_airline.loc[676,"Rating"]="5.11166"
df_airline.loc[677,"Rating"]="5.11167"
df_airline.loc[678,"Rating"]="5.11168"
df_airline.loc[679,"Rating"]="5.11169"
df_airline.loc[680,"Rating"]="5.11170"
df_airline.loc[681,"Rating"]="5.11171"
df_airline.loc[682,"Rating"]="5.11172"
df_airline.loc[683,"Rating"]="5.11173"
df_airline.loc[684,"Rating"]="5.11174"
df_airline.loc[685,"Rating"]="5.11175"
df_airline.loc[686,"Rating"]="5.11176"
df_airline.loc[687,"Rating"]="5.11177"
df_airline.loc[688,"Rating"]="5.11178"
df_airline.loc[689,"Rating"]="5.11179"
df_airline.loc[690,"Rating"]="5.11180"
df_airline.loc[691,"Rating"]="5.11181"
df_airline.loc[692,"Rating"]="5.11182"
df_airline.loc[693,"Rating"]="5.11183"
df_airline.loc[694,"Rating"]="5.11184"
df_airline.loc[695,"Rating"]="5.11185"
df_airline.loc[696,"Rating"]="5.11186"
df_airline.loc[697,"Rating"]="5.11187"
df_airline.loc[698,"Rating"]="5.11188"
df_airline.loc[699,"Rating"]="5.11189"
df_airline.loc[700,"Rating"]="5.11190"
df_airline.loc[701,"Rating"]="5.11191"
df_airline.loc[702,"Rating"]="5.11192"
df_airline.loc[703,"Rating"]="5.11193"
df_airline.loc[704,"Rating"]="5.11194"
df_airline.loc[705,"Rating"]="5.11195"
df_airline.loc[706,"Rating"]="5.11196"
df_airline.loc[707,"Rating"]="5.11197"
df_airline.loc[708,"Rating"]="5.11198"
df_airline.loc[709,"Rating"]="5.11199"
df_airline.loc[710,"Rating"]="5.11200"
df_airline.loc[711,"Rating"]="5.11201"
df_airline.loc[712,"Rating"]="5.11202"
df_airline.loc[713,"Rating"]="5.11203"
df_airline.loc[714,"Rating"]="5.11204"
df_airline.loc[715,"Rating"]="5.11205"
df_airline.loc[716,"Rating"]="5.11206"
df_airline.loc[717,"Rating"]="5.11207"
df_airline.loc[718,"Rating"]="5.11208"
df_airline.loc[719,"Rating"]="5.11209"
df_airline.loc[720,"Rating"]="5.11210"
df_airline.loc[721,"Rating"]="5.11211"
df_airline.loc[722,"Rating"]="5.11212"
df_airline.loc[723,"Rating"]="5.11213"
df_airline.loc[724,"Rating"]="5.11214"
df_airline.loc[725,"Rating"]="5.11215"
df_airline.loc[726,"Rating"]="5.11216"
df_airline.loc[727,"Rating"]="5.11217"
df_airline.loc[728,"Rating"]="5.11218"
df_airline.loc[729,"Rating"]="5.11219"
df_airline.loc[730,"Rating"]="5.11220"
df_airline.loc[731,"Rating"]="5.11221"
df_airline.loc[732,"Rating"]="5.11222"
df_airline.loc[734,"Rating"]="5.11223"
df_airline.loc[733,"Rating"]="5.11224"
df_airline.loc[734,"Rating"]="5.11225"
df_airline.loc[735,"Rating"]="5.11226"
df_airline.loc[736,"Rating"]="5.11227"
df_airline.loc[737,"Rating"]="5.11228"
df_airline.loc[738,"Rating"]="5.11229"
df_airline.loc[739,"Rating"]="5.11230"
df_airline.loc[740,"Rating"]="5.11231"
df_airline.loc[741,"Rating"]="5.11230"
df_airline.loc[742,"Rating"]="5.11232"
df_airline.loc[743,"Rating"]="5.11233"
df_airline.loc[744,"Rating"]="5.11234"
df_airline.loc[745,"Rating"]="5.11235"
df_airline.loc[746,"Rating"]="5.11236"
df_airline.loc[747,"Rating"]="5.11237"
df_airline.loc[748,"Rating"]="5.11238"
df_airline.loc[749,"Rating"]="5.11239"
df_airline.loc[750,"Rating"]="5.11240"
df_airline.loc[751,"Rating"]="5.11241"
df_airline.loc[752,"Rating"]="5.11242"
df_airline.loc[753,"Rating"]="5.11243"
df_airline.loc[754,"Rating"]="5.11244"
df_airline.loc[755,"Rating"]="5.11245"
df_airline.loc[756,"Rating"]="5.11246"
df_airline.loc[757,"Rating"]="5.11247"
df_airline.loc[758,"Rating"]="5.11248"
df_airline.loc[759,"Rating"]="5.11249"
df_airline.loc[760,"Rating"]="5.11250"
df_airline.loc[761,"Rating"]="3.21111"
df_airline.loc[762,"Rating"]="3.31112"
df_airline.loc[763,"Rating"]="3.41113"
df_airline.loc[764,"Rating"]="3.51114"
df_airline.loc[765,"Rating"]="3.61115"
df_airline.loc[766,"Rating"]="3.71116"
df_airline.loc[767,"Rating"]="3.81117"
df_airline.loc[768,"Rating"]="3.91118"
df_airline.loc[769,"Rating"]="3.13119"
df_airline.loc[770,"Rating"]="3.14110"
df_airline.loc[771,"Rating"]="3.15111"
df_airline.loc[772,"Rating"]="3.16112"
df_airline.loc[773,"Rating"]="3.17113"
df_airline.loc[774,"Rating"]="2.21114"
df_airline.loc[775,"Rating"]="3.31115"
df_airline.loc[776,"Rating"]="3.41116"
df_airline.loc[777,"Rating"]="3.51117"
df_airline.loc[778,"Rating"]="3.61118"
df_airline.loc[779,"Rating"]="3.71119"
df_airline.loc[780,"Rating"]="3.81120"
df_airline.loc[781,"Rating"]="3.91121"
df_airline.loc[782,"Rating"]="3.10122"
df_airline.loc[783,"Rating"]="3.12123"
df_airline.loc[784,"Rating"]="3.31124"
df_airline.loc[785,"Rating"]="3.14125"
df_airline.loc[786,"Rating"]="3.15126"
df_airline.loc[787,"Rating"]="3.16127"
df_airline.loc[788,"Rating"]="3.17128"
df_airline.loc[789,"Rating"]="3.18129"
df_airline.loc[790,"Rating"]="3.19130"
df_airline.loc[791,"Rating"]="3.11031"
df_airline.loc[792,"Rating"]="3.11232"
df_airline.loc[793,"Rating"]="3.11333"
df_airline.loc[794,"Rating"]="3.11434"
df_airline.loc[795,"Rating"]="3.11535"
df_airline.loc[796,"Rating"]="3.11636"
df_airline.loc[797,"Rating"]="3.11737"
df_airline.loc[798,"Rating"]="3.11838"
df_airline.loc[799,"Rating"]="3.11939"
df_airline.loc[800,"Rating"]="3.11040"

# %%
#Data dictionary
df11 = df_airline.to_dict('Index')
df11
# Out:
# {0: {'Company Maker': 'A. Morin',
#   'Specific Bean Origin or Bar Name': 'Agua Grande',
#   'REF': 1876,
#   'Review Date': '2016-02-01',
#   'Cocoa Percent': 63.0,
#   'Company Location': 'France',
#   'Rating': '1.11111',
#   'Bean Type': 'xao',
#   'Broad Bean Origin': 'Sao Tome'},
#  1: {'Company Maker': 'A. Morin',
#   'Specific Bean Origin or Bar Name': 'Kpime',
#   'REF': 1676,
#   'Review Date': '2015-02-01',
#   'Cocoa Percent': 70.0,
#   'Company Location': 'France',
#   'Rating': '1.11112',
#   'Bean Type': 'xao',
#   'Broad Bean Origin': 'Togo'},
#  2: {'Company Maker': 'A. Morin',
#   'Specific Bean Origin or Bar Name': 'Atsane',
#   'REF': 1676,
#   'Review Date': '2015-03-01',
#   'Cocoa Percent': 70.0,
#   'Company Location': 'France',
#   'Rating': '1.11113',
#   'Bean Type': 'xao',
#   'Broad Bean Origin': 'Togo'},
#  3: {'Company Maker': 'A. Morin',
#   'Specific Bean Origin or Bar Name': 'Akata',
#   'REF': 1680,
#   'Review Date': '2015-04-01',
# ...

# %%
 ## Exporting the data
df_airline.to_csv(os.path.join(path, '02 Data','Prepared Data for storing any manipulated data sets', 'flavors_of_cacao_check.csv'))
